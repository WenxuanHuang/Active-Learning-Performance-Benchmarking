# %%
print(__doc__)

import os
import time
import json
import pickle
import math

import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
from scipy.special import expit
from scipy import stats
from pylab import rcParams
import mplcursors

from sklearn.utils import check_random_state
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import RFE
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler

from sklearn import linear_model
from sklearn import neighbors
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso
from sklearn.svm import LinearSVC, SVC
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.utils import check_random_state
from sklearn.metrics import accuracy_score
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from sklearn.naive_bayes import GaussianNB

from sklearn import metrics
from sklearn.metrics import pairwise_distances_argmin_min
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score


# pd.options.display.max_rows = 20
pd.options.display.float_format = "{:.1f}".format

max_queried = 500
trainset_size = 1302
# Out:
# Automatically created module for IPython interactive environment

# %%
def data_prep():
    data = pd.read_csv("https://raw.githubusercontent.com/WenxuanHuang/ML-for-COVID-19-dataset/main/all_training.csv", sep=',')
    # Column selection
    df = data.iloc[:,np.r_[3:34]].copy()
    # define row and column index
    col = df.columns
    row = [i for i in range(df.shape[0])]
    # define imputer
    imputer = IterativeImputer(estimator=linear_model.BayesianRidge(), n_nearest_features=None, imputation_order='ascending')
    # fit on the dataset
    imputer.fit(df)
    # transform the dataset
    df_imputed = imputer.transform(df)
    # convert back to pandas dataframe and rename back to df_normalized
    df = pd.DataFrame(data=df_imputed, index=row, columns=col)
    X = df
    y = data.target    
    # Recursive feature elimination
    rdmreg = RandomForestClassifier(n_estimators=100)
    # Define the method
    rfe = RFE(estimator=rdmreg, n_features_to_select=10)
    # Fit the model
    rfe = rfe.fit(X, y.values.ravel())
    print(rfe.support_)
    # Drop columns that failed RFE test
    col = df.columns[rfe.support_]
    X = X[col]
    X = X.to_numpy()
    print ('df:', X.shape, y.shape)
    return (X, y)


def split(train_size):
    X_train_full = X[:train_size]
    y_train_full = y[:train_size]
    X_test = X[train_size:]
    y_test = y[train_size:]   
    return (X_train_full, y_train_full, X_test, y_test)

# %%
class BaseModel(object):

    def __init__(self):
        pass

    def fit_predict(self):
        pass


class SvmModel(BaseModel):

    model_type = 'Support Vector Machine with linear Kernel'
    def fit_predict(self, X_train, y_train, X_val, X_test, c_weight):
        print ('training svm...')
        self.classifier = SVC(
            C=1, 
            kernel='linear', 
            probability=True,
            class_weight=c_weight
            )
        self.classifier.fit(X_train, y_train)
        self.test_y_predicted = self.classifier.predict(X_test)
        self.val_y_predicted = self.classifier.predict(X_val)
        return (X_train, X_val, X_test, self.val_y_predicted,
                self.test_y_predicted)

class LogModel(BaseModel):

    model_type = 'Logistic Regression' 
    def fit_predict(self, X_train, y_train, X_val, X_test, c_weight):
        print ('training logistic regression...')
        # train_samples = X_train.shape[0]
        self.classifier = LogisticRegression(
            # C=50. / train_samples,
            penalty='l1',
            solver='liblinear',
            tol=0.1,
            class_weight=c_weight
            )
        self.classifier.fit(X_train, y_train)
        self.test_y_predicted = self.classifier.predict(X_test)
        self.val_y_predicted = self.classifier.predict(X_val)
        return (X_train, X_val, X_test, self.val_y_predicted,
                self.test_y_predicted)

class RfModel(BaseModel):

    model_type = 'Random Forest'
    def fit_predict(self, X_train, y_train, X_val, X_test, c_weight):
        print ('training random forest...')
        self.classifier = RandomForestClassifier(
            n_estimators=500, 
            class_weight=c_weight, 
            n_jobs=-1
            )
        self.classifier.fit(X_train, y_train)
        self.test_y_predicted = self.classifier.predict(X_test)
        self.val_y_predicted = self.classifier.predict(X_val)
        return (X_train, X_val, X_test, self.val_y_predicted, self.test_y_predicted)

class GDBCModel(BaseModel):

    model_type = 'Gradient Boost classifier'
    def fit_predict(self, X_train, y_train, X_val, X_test, c_weight):
        print ('training GDBC...')
        self.classifier = GradientBoostingClassifier(
            n_estimators=1200,
            max_depth=3,
            subsample=0.5,
            learning_rate=0.01,
            min_samples_leaf=1,
            random_state=3
            )
        self.classifier.fit(X_train, y_train)
        self.test_y_predicted = self.classifier.predict(X_test)
        self.val_y_predicted = self.classifier.predict(X_val)
        return (X_train, X_val, X_test, self.val_y_predicted, self.test_y_predicted)

class KnnModel(BaseModel):

    model_type = 'Nearest Neighbour classifier'
    def fit_predict(self, X_train, y_train, X_val, X_test, c_weight):
        print ('training KNN...')
        self.classifier = neighbors.KNeighborsClassifier(
            n_neighbors = 10,
            n_jobs = -1
            )
        self.classifier.fit(X_train, y_train)
        self.test_y_predicted = self.classifier.predict(X_test)
        self.val_y_predicted = self.classifier.predict(X_val)
        return (X_train, X_val, X_test, self.val_y_predicted, self.test_y_predicted)

# %%
class TrainModel:

    def __init__(self, model_object):        
        self.accuracies = []
        self.model_object = model_object()        

    def print_model_type(self):
        print (self.model_object.model_type)

    # we train normally and use the probabilities to select the most uncertain samples
    def train(self, X_train, y_train, X_val, X_test, c_weight):
        print ('Train set:', X_train.shape)
        print ('Validation set:', X_val.shape)
        print ('Test set:', X_test.shape)
        t0 = time.time()
        (X_train, X_val, X_test, self.val_y_predicted,
         self.test_y_predicted) = \
            self.model_object.fit_predict(X_train, y_train, X_val, X_test, c_weight)
        self.run_time = time.time() - t0
        return (X_train, X_val, X_test)

    # we want accuracy only for the test set
    def get_test_accuracy(self, i, y_test):
        classif_rate = np.mean(self.test_y_predicted.ravel() == y_test.ravel()) * 100
        self.accuracies.append(classif_rate)               
        print('--------------------------------')
        print('Iteration:',i)
        print('--------------------------------')
        print('y-test set:',y_test.shape)
        print('Training run in %.3f s' % self.run_time,'\n')
        print("Accuracy rate is %f " % (classif_rate))    
        print("Classification report for %s:\n%s\n" % (self.model_object.classifier, metrics.classification_report(y_test, self.test_y_predicted)))
        print("Confusion matrix:\n%s" % metrics.confusion_matrix(y_test, self.test_y_predicted))
        print('--------------------------------')

# %%
class QueryFunction(object):

    def __init__(self):
        pass

    def stream_select(self):
        pass

    def pool_select(self):
        pass


class RandomSelection(QueryFunction):

    @staticmethod
    def pool_select(probas_val, batch_size):
        random_state = check_random_state(0)
        # probas_val.shape[0] is the size of validation set
        selection = np.random.choice(probas_val.shape[0], batch_size, replace=False)
        print('uniques chosen:',np.unique(selection).shape[0],'<= should be equal to:',batch_size)
        return selection


class EntropySelection(QueryFunction):

    @staticmethod
    def pool_select(probas_val, batch_size):
        e = (-probas_val * np.log2(probas_val)).sum(axis=1)
        selection = (np.argsort(e)[::-1])[:batch_size]
        return selection

class MinStdSelection(QueryFunction):

    # select the samples where the std is smallest. There is uncertainty regarding the relevant class
    # and then train on these "hard" to classify samples.
    @staticmethod
    def pool_select(probas_val, batch_size):
        std = np.std(probas_val * 100, axis=1) 
        selection = std.argsort()[:batch_size]
        selection = selection.astype('int64')
        print('std',std.shape,std)
        print('selection',selection, selection.shape, std[selection])
        return selection

class LeastConfidenceSelection(QueryFunction):

    @staticmethod
    def pool_select(probas_val, batch_size):
        sort_prob = -np.sort(-probas_val, axis=1)
        values = sort_prob[:, 0]
        selection = np.argsort(values)[:batch_size]
        return selection
      
      
class MarginSamplingSelection(QueryFunction):

    @staticmethod
    def pool_select(probas_val, batch_size):
        sort_prob = -np.sort(-probas_val, axis=1)
        values = sort_prob[:, 0] - sort_prob[:, 1]
        selection = np.argsort(values)[:batch_size]
        return selection

# %%
class Normalize(object):
    
    def normalize(self, X_train, X_val, X_test):
        self.scaler = RobustScaler()
        X_train = self.scaler.fit_transform(X_train)
        X_val   = self.scaler.transform(X_val)
        X_test  = self.scaler.transform(X_test)
        return (X_train, X_val, X_test) 
    
    def inverse(self, X_train, X_val, X_test):
        X_train = self.scaler.inverse_transform(X_train)
        X_val   = self.scaler.inverse_transform(X_val)
        X_test  = self.scaler.inverse_transform(X_test)
        return (X_train, X_val, X_test)

# %%
def get_random_samples(initial_samples, X_train_full,
                         y_train_full):

    random_state = check_random_state(0)

    permutation = np.random.choice(len(X_train_full),initial_samples,replace=False)
    
    # print ()
    # print(type(permutation))
    # print ('initial random chosen samples', permutation)

    X_train = X_train_full[permutation]
    y_train = y_train_full[permutation]
    X_train = X_train.reshape((X_train.shape[0], -1))

    # bin_count = np.bincount(y_train.astype('int64'))
    # unique = np.unique(y_train.astype('int64'))
    # print (
    #     'initial train set:',
    #     X_train.shape,
    #     y_train.shape,
    #     'unique(labels):',
    #     bin_count,
    #     unique,
    #     )
    return (permutation, X_train, y_train)

# %%
class TheAlgorithm(object):

    accuracies = []

    def __init__(self, init_samples, model_object, selection_function):
        self.init_samples = init_samples
        self.model_object = model_object
        self.sample_selection_function = selection_function
        
# To-do: Move initiation selections as arguments
    def run(self, X_train_full, y_train_full, X_test, y_test, initial_queried, max_queried):

        # initialize process by applying base learner to labeled training data set to obtain Classifier
        (permutation, X_train, y_train) = \
            get_random_samples(initial_queried, X_train_full, y_train_full)
        self.queried = initial_queried
        # self.samplecount = [self.initiation_selections]

        # assign the val set the rest of the 'unlabelled' training data
        X_val = np.array([])
        y_val = np.array([])
        X_val = np.copy(X_train_full)
        X_val = np.delete(X_val, permutation, axis=0)
        y_val = np.copy(y_train_full)
        y_val = np.delete(y_val, permutation, axis=0)
        # print ('Val set:', X_val.shape, y_val.shape, permutation.shape)
        # print ()

        # normalize data
        normalizer = Normalize()
        X_train, X_val, X_test = normalizer.normalize(X_train, X_val, X_test)
           
        self.clf_model = TrainModel(self.model_object)
        (X_train, X_val, X_test) = self.clf_model.train(X_train, y_train, X_val, X_test, 'balanced')
        active_iteration = 1
        self.clf_model.get_test_accuracy(1, y_test)

        while self.queried < max_queried:

            active_iteration += 1

            # get validation probabilities
            probas_val = \
                self.clf_model.model_object.classifier.predict_proba(X_val)
            # print('Probas_val:', probas_val)
            # pred_val = \
            #     self.clf_model.val_y_predicted
            # model_val = \
            #     self.clf_model
            # print ('val predicted:',
            #         self.clf_model.val_y_predicted.shape,
            #         self.clf_model.val_y_predicted)
            # display probability of binary value predictions of the validation set
            # print ('probas_val value', probas_val)
            # display which binary value has the highest probabilities of the validation set
            # print ('probabilities:', probas_val.shape, '\n',
            #        np.argmax(probas_val, axis=1))

            # select samples using a selection function
            uncertain_samples = self.sample_selection_function.pool_select(probas_val, self.init_samples)

            # normalization needs to be inversed and recalculated based on the new train and test set.
            X_train, X_val, X_test = normalizer.inverse(X_train, X_val, X_test)   

            # get the uncertain samples from the validation set
            # print ('trainset before adding uncertain samples', X_train.shape, y_train.shape)
            X_train = np.concatenate((X_train, X_val[uncertain_samples]))
            y_train = np.concatenate((y_train, y_val[uncertain_samples]))
            # print ('trainset after adding uncertain samples', X_train.shape, y_train.shape)
            # self.samplecount.append(X_train.shape[0])

            # bin_count = np.bincount(y_train.astype('int64'))
            # unique = np.unique(y_train.astype('int64'))
            # print (
            #     'updated train set:',
            #     X_train.shape,
            #     y_train.shape,
            #     'unique(labels):',
            #     bin_count,
            #     unique,
            #     )

            X_val = np.delete(X_val, uncertain_samples, axis=0)
            y_val = np.delete(y_val, uncertain_samples, axis=0)
            # print ('val set:', X_val.shape, y_val.shape)
            # print ()

            # normalize again after creating the 'new' train/test sets
            normalizer = Normalize()
            X_train, X_val, X_test = normalizer.normalize(X_train, X_val, X_test)               

            self.queried += self.init_samples
            (X_train, X_val, X_test) = self.clf_model.train(X_train, y_train, X_val, X_test, 'balanced')
            self.clf_model.get_test_accuracy(active_iteration, y_test)

        return self.clf_model.accuracies
        # print ('final active learning accuracies',
        #        self.clf_model.accuracies)

# %%
def pool_experiment(model,sampling_method,max_queried,initial_queried):
    (X, y) = data_prep()
    # (X_train_full, X_test,y_train_full,  y_test) = train_test_split(X, y, test_size=0.25)
    # print(type(X_train_full))

    kf = KFold(n_splits=4)

    for train_index, test_index in kf.split(X):
        X_train_full, X_test = X[train_index], X[test_index]
        y_train_full, y_test = y[train_index], y[test_index]
        
    act_alg = TheAlgorithm(1,model , sampling_method)
    accuracies = act_alg.run(X_train_full,y_train_full,X_test,y_test,initial_queried,max_queried)

    (permutation, X_train_selected, y_train_selected) = get_random_samples(initial_queried, X_train_full, y_train_full)
    original_accuracies=[]
    classifier_original = LogisticRegression(C=50. / X_train_full.shape[0],
            penalty='l1',
            solver='liblinear',
            tol=0.1,
            class_weight='balanced')

    for i in range(initial_queried-1,max_queried):
        classifier_original.fit(X_train_selected[:i+1], y_train_selected[:i+1])
        y_pred_random = classifier_original.predict(X_test)
        original_accuracies.append(accuracy_score(y_test, y_pred_random)*100)
    print("accuracies",accuracies)
    print("nonactive_accuracies",original_accuracies)
    x_axis = np.linspace(initial_queried,max_queried,num=max_queried - initial_queried +1,endpoint=True)
    plt.plot(x_axis, accuracies, 'r',label='active') 
    plt.plot(x_axis, original_accuracies, 'blue',label='non-active') 
    plt.legend()
    plt.xlabel('Sample Size')
    plt.ylabel('Accuracy')
    plt.show()

# %%
# print ('train:', X_train_full.shape, y_train_full.shape)
# print ('test :', X_test.shape, y_test.shape)
# classes = len(np.unique(y))
# print ('unique classes', classes)

# def pickle_save(fname, data):
#   filehandler = open(fname,"wb")
#   pickle.dump(data,filehandler)
#   filehandler.close()
#   print('saved', fname, os.getcwd(), os.listdir())

# def pickle_load(fname):
#   print(os.getcwd(), os.listdir())
#   file = open(fname,'rb')
#   data = pickle.load(file)
#   file.close()
#   print(data)
#   return data
  
def batch_experiment(d, models, selection_functions, Ks, repeats, contfrom):

    (X, y) = data_prep()
    # (X_train_full, X_test,y_train_full,  y_test) = train_test_split(X, y, test_size=0.25)
    # print(type(X_train_full))

    from sklearn.model_selection import KFold
    kf = KFold(n_splits=4)

    for train_index, test_index in kf.split(X):
        X_train_full, X_test = X[train_index], X[test_index]
        y_train_full, y_test = y[train_index], y[test_index]

    algos_temp = []
    print ('stopping at:', max_queried)
    count = 0
    for model_object in models:
      if model_object.__name__ not in d:
          d[model_object.__name__] = {}
      
      for selection_function in selection_functions:
        if selection_function.__name__ not in d[model_object.__name__]:
            d[model_object.__name__][selection_function.__name__] = {}
        
        for k in Ks:
            d[model_object.__name__][selection_function.__name__][str(k)] = []           
            
            for i in range(0, repeats):
                count+=1
                if count >= contfrom:
                    # print ('Count = %s, using model = %s, selection_function = %s, k = %s, iteration = %s.' % (count, model_object.__name__, selection_function.__name__, k, i))
                    alg = TheAlgorithm(k, 
                                       model_object, 
                                       selection_function
                                       )
                    alg.run(X_train_full, y_train_full, X_test, y_test)
                    d[model_object.__name__][selection_function.__name__][str(k)].append(alg.clf_model.accuracies)
                    # fname = '/Users/wenxuanhuang/Documents/Repo/ML-for-COVID-19-dataset/Results/Active-learning-experiment-' + str(count) + '.pkl'
                    # pickle_save(fname, d)
                    # if count % 5 == 0:
                    #     print(json.dumps(d, indent=2, sort_keys=True))
                    # print ()
                    # print ('---------------------------- FINISHED ---------------------------')
                    # print ()
    return d


# max_queried = 500 
# repeats = 1
# models = [LogModel] 
# # models = [SvmModel, RfModel, LogModel, GDBCModel, KnnModel] 
# selection_functions = [LeastConfidenceSelection] 
# # selection_functions = [RandomSelection, MarginSamplingSelection, EntropySelection, MinStdSelection, LeastConfidenceSelection] 
# Ks = [250,125,50,25,10] 
# d = {}
# stopped_at = -1 
# # print('directory dump including pickle files:', os.getcwd(), np.sort(os.listdir()))  
# # d = pickle_load('Active-learning-experiment-' + str(stopped_at) + '.pkl')  
# # print(json.dumps(d, indent=2, sort_keys=True))
# d = batch_experiment(d, models, selection_functions, Ks, repeats, stopped_at+1)
# # print (d)
# # results = json.loads(json.dumps(d, indent=2, sort_keys=True))
# # print(results)

# %%
# %matplotlib widget
# # %matplotlib inline
# def performance_plot(fully_supervised_accuracy, dic, models, selection_functions, Ks, repeats):  
#     fig, ax = plt.subplots()
#     ax.plot([0,500],[fully_supervised_accuracy, fully_supervised_accuracy],label = 'upper-bound')
#     for model_object in models:
#       for selection_function in selection_functions:
#         for idx, k in enumerate(Ks):
#             x = np.arange(float(Ks[idx]), 500 + float(Ks[idx]), float(Ks[idx]))            
#             Sum = np.array(dic[model_object][selection_function][k][0])
#             for i in range(1, repeats):
#                 Sum = Sum + np.array(dic[model_object][selection_function][k][i])
#             mean = Sum / repeats
#             ax.plot(x, mean, label = model_object[0:3] + '-' + selection_function[0:3] + '-' + str(k))
#     ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
#     ax.set_xlim([50,500])
#     ax.set_ylim([20,83])
#     ax.grid(True)
#     mplcursors.cursor()
#     plt.tight_layout()
#     plt.show()

# # models_str = ['SvmModel', 'RfModel', 'LogModel','GDBCModel','KnnModel']
# models_str = ['LogModel']
# # selection_functions_str = ['RandomSelection', 'MarginSamplingSelection', 'EntropySelection', 'MinStdSelection','LeastConfidenceSelection']
# selection_functions_str = ['LeastConfidenceSelection']
# Ks_str = ['250','125','50','25','10'] 
# repeats = 10
# # random_forest_upper_bound = 89.
# # svm_upper_bound = 87.
# log_upper_bound = 87.
# # gdbc_upper_bound = 86.
# # knn_upper_bound = 86.
# total_experiments = len(models_str) * len(selection_functions_str) * len(Ks_str) * repeats

# print('So which is the better model? under the stopping condition and hyper parameters')
# # performance_plot(random_forest_upper_bound, d, ['RfModel'] , selection_functions_str    , Ks_str, 1)
# # performance_plot(svm_upper_bound, d, ['SvmModel'] , selection_functions_str    , Ks_str, 1)
# performance_plot(log_upper_bound, d, ['LogModel'] , selection_functions_str    , Ks_str, 1)
# # performance_plot(gdbc_upper_bound, d, ['GDBCModel'] , selection_functions_str    , Ks_str, 1)
# # performance_plot(log_upper_bound, d, ['KnnModel'] , selection_functions_str    , Ks_str, 1)

# %%
pool_experiment(LogModel,LeastConfidenceSelection,500,25)
# Out:
# [ True False False False False False  True False  True  True False False
#  False  True  True False False False False False False False False False
#   True  True  True False False  True False]
# df: (1736, 10) (1736,)
# Train set: (25, 10)
# Validation set: (1277, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 1
# --------------------------------
# y-test set: (434,)
# Training run in 0.001 s
#
# Accuracy rate is 75.345622
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.84      0.83      0.83       321
#            1       0.53      0.54      0.53       113
#
#     accuracy                           0.75       434
#    macro avg       0.68      0.68      0.68       434
# weighted avg       0.76      0.75      0.75       434
#
#
# Confusion matrix:
# [[266  55]
#  [ 52  61]]
# --------------------------------
# Train set: (26, 10)
# Validation set: (1276, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 2
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 75.576037
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.84      0.82      0.83       321
#            1       0.53      0.57      0.55       113
#
#     accuracy                           0.76       434
#    macro avg       0.69      0.69      0.69       434
# weighted avg       0.76      0.76      0.76       434
#
#
# Confusion matrix:
# [[264  57]
#  [ 49  64]]
# --------------------------------
# Train set: (27, 10)
# Validation set: (1275, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 3
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 77.649770
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85       321
#            1       0.57      0.57      0.57       113
#
#     accuracy                           0.78       434
#    macro avg       0.71      0.71      0.71       434
# weighted avg       0.78      0.78      0.78       434
#
#
# Confusion matrix:
# [[273  48]
#  [ 49  64]]
# --------------------------------
# Train set: (28, 10)
# Validation set: (1274, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 4
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 76.728111
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.85      0.83      0.84       321
#            1       0.55      0.58      0.56       113
#
#     accuracy                           0.77       434
#    macro avg       0.70      0.71      0.70       434
# weighted avg       0.77      0.77      0.77       434
#
#
# Confusion matrix:
# [[268  53]
#  [ 48  65]]
# --------------------------------
# Train set: (29, 10)
# Validation set: (1273, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 5
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 78.801843
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.84      0.88      0.86       321
#            1       0.61      0.53      0.57       113
#
#     accuracy                           0.79       434
#    macro avg       0.72      0.70      0.71       434
# weighted avg       0.78      0.79      0.78       434
#
#
# Confusion matrix:
# [[282  39]
#  [ 53  60]]
# --------------------------------
# Train set: (30, 10)
# Validation set: (1272, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 6
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 78.341014
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.84      0.87      0.86       321
#            1       0.59      0.54      0.56       113
#
#     accuracy                           0.78       434
#    macro avg       0.72      0.70      0.71       434
# weighted avg       0.78      0.78      0.78       434
#
#
# Confusion matrix:
# [[279  42]
#  [ 52  61]]
# --------------------------------
# Train set: (31, 10)
# Validation set: (1271, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 7
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 78.801843
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.84      0.88      0.86       321
#            1       0.61      0.53      0.57       113
#
#     accuracy                           0.79       434
#    macro avg       0.72      0.70      0.71       434
# weighted avg       0.78      0.79      0.78       434
#
#
# Confusion matrix:
# [[282  39]
#  [ 53  60]]
# --------------------------------
# Train set: (32, 10)
# Validation set: (1270, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 8
# --------------------------------
# y-test set: (434,)
# Training run in 0.001 s
#
# Accuracy rate is 78.571429
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.84      0.88      0.86       321
#            1       0.60      0.51      0.56       113
#
#     accuracy                           0.79       434
#    macro avg       0.72      0.70      0.71       434
# weighted avg       0.78      0.79      0.78       434
#
#
# Confusion matrix:
# [[283  38]
#  [ 55  58]]
# --------------------------------
# Train set: (33, 10)
# Validation set: (1269, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 9
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 77.880184
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.84      0.86      0.85       321
#            1       0.58      0.55      0.56       113
#
#     accuracy                           0.78       434
#    macro avg       0.71      0.70      0.71       434
# weighted avg       0.78      0.78      0.78       434
#
#
# Confusion matrix:
# [[276  45]
#  [ 51  62]]
# --------------------------------
# Train set: (34, 10)
# Validation set: (1268, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 10
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 78.571429
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.84      0.87      0.86       321
#            1       0.60      0.54      0.57       113
#
#     accuracy                           0.79       434
#    macro avg       0.72      0.71      0.71       434
# weighted avg       0.78      0.79      0.78       434
#
#
# Confusion matrix:
# [[280  41]
#  [ 52  61]]
# --------------------------------
# Train set: (35, 10)
# Validation set: (1267, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 11
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 77.419355
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.84      0.85      0.85       321
#            1       0.57      0.55      0.56       113
#
#     accuracy                           0.77       434
#    macro avg       0.71      0.70      0.70       434
# weighted avg       0.77      0.77      0.77       434
#
#
# Confusion matrix:
# [[274  47]
#  [ 51  62]]
# --------------------------------
# Train set: (36, 10)
# Validation set: (1266, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 12
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 78.801843
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.84      0.89      0.86       321
#            1       0.61      0.50      0.55       113
#
#     accuracy                           0.79       434
#    macro avg       0.72      0.70      0.71       434
# weighted avg       0.78      0.79      0.78       434
#
#
# Confusion matrix:
# [[285  36]
#  [ 56  57]]
# --------------------------------
# Train set: (37, 10)
# Validation set: (1265, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 13
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 78.571429
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.84      0.87      0.86       321
#            1       0.60      0.54      0.57       113
#
#     accuracy                           0.79       434
#    macro avg       0.72      0.71      0.71       434
# weighted avg       0.78      0.79      0.78       434
#
#
# Confusion matrix:
# [[280  41]
#  [ 52  61]]
# --------------------------------
# Train set: (38, 10)
# Validation set: (1264, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 14
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 79.262673
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.86       321
#            1       0.61      0.56      0.58       113
#
#     accuracy                           0.79       434
#    macro avg       0.73      0.72      0.72       434
# weighted avg       0.79      0.79      0.79       434
#
#
# Confusion matrix:
# [[281  40]
#  [ 50  63]]
# --------------------------------
# Train set: (39, 10)
# Validation set: (1263, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 15
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 77.419355
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.84      0.85      0.85       321
#            1       0.57      0.55      0.56       113
#
#     accuracy                           0.77       434
#    macro avg       0.71      0.70      0.70       434
# weighted avg       0.77      0.77      0.77       434
#
#
# Confusion matrix:
# [[274  47]
#  [ 51  62]]
# --------------------------------
# Train set: (40, 10)
# Validation set: (1262, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 16
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 76.958525
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.84      0.85      0.84       321
#            1       0.56      0.55      0.55       113
#
#     accuracy                           0.77       434
#    macro avg       0.70      0.70      0.70       434
# weighted avg       0.77      0.77      0.77       434
#
#
# Confusion matrix:
# [[272  49]
#  [ 51  62]]
# --------------------------------
# Train set: (41, 10)
# Validation set: (1261, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 17
# --------------------------------
# y-test set: (434,)
# Training run in 0.001 s
#
# Accuracy rate is 78.571429
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.85      0.86      0.86       321
#            1       0.59      0.57      0.58       113
#
#     accuracy                           0.79       434
#    macro avg       0.72      0.71      0.72       434
# weighted avg       0.78      0.79      0.78       434
#
#
# Confusion matrix:
# [[277  44]
#  [ 49  64]]
# --------------------------------
# Train set: (42, 10)
# Validation set: (1260, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 18
# --------------------------------
# y-test set: (434,)
# Training run in 0.003 s
#
# Accuracy rate is 78.341014
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.84      0.87      0.86       321
#            1       0.59      0.55      0.57       113
#
#     accuracy                           0.78       434
#    macro avg       0.72      0.71      0.71       434
# weighted avg       0.78      0.78      0.78       434
#
#
# Confusion matrix:
# [[278  43]
#  [ 51  62]]
# --------------------------------
# Train set: (43, 10)
# Validation set: (1259, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 19
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 77.419355
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85       321
#            1       0.57      0.57      0.57       113
#
#     accuracy                           0.77       434
#    macro avg       0.71      0.71      0.71       434
# weighted avg       0.77      0.77      0.77       434
#
#
# Confusion matrix:
# [[272  49]
#  [ 49  64]]
# --------------------------------
# Train set: (44, 10)
# Validation set: (1258, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 20
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 78.801843
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.84      0.88      0.86       321
#            1       0.60      0.54      0.57       113
#
#     accuracy                           0.79       434
#    macro avg       0.72      0.71      0.71       434
# weighted avg       0.78      0.79      0.78       434
#
#
# Confusion matrix:
# [[281  40]
#  [ 52  61]]
# --------------------------------
# Train set: (45, 10)
# Validation set: (1257, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 21
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 78.801843
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.85      0.87      0.86       321
#            1       0.60      0.56      0.58       113
#
#     accuracy                           0.79       434
#    macro avg       0.72      0.71      0.72       434
# weighted avg       0.78      0.79      0.79       434
#
#
# Confusion matrix:
# [[279  42]
#  [ 50  63]]
# --------------------------------
# Train set: (46, 10)
# Validation set: (1256, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 22
# --------------------------------
# y-test set: (434,)
# Training run in 0.001 s
#
# Accuracy rate is 79.493088
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.86       321
#            1       0.62      0.54      0.58       113
#
#     accuracy                           0.79       434
#    macro avg       0.73      0.71      0.72       434
# weighted avg       0.79      0.79      0.79       434
#
#
# Confusion matrix:
# [[284  37]
#  [ 52  61]]
# --------------------------------
# Train set: (47, 10)
# Validation set: (1255, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 23
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 78.801843
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.84      0.88      0.86       321
#            1       0.61      0.53      0.57       113
#
#     accuracy                           0.79       434
#    macro avg       0.72      0.70      0.71       434
# weighted avg       0.78      0.79      0.78       434
#
#
# Confusion matrix:
# [[282  39]
#  [ 53  60]]
# --------------------------------
# Train set: (48, 10)
# Validation set: (1254, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 24
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 78.801843
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.84      0.88      0.86       321
#            1       0.61      0.53      0.57       113
#
#     accuracy                           0.79       434
#    macro avg       0.72      0.70      0.71       434
# weighted avg       0.78      0.79      0.78       434
#
#
# Confusion matrix:
# [[282  39]
#  [ 53  60]]
# --------------------------------
# Train set: (49, 10)
# Validation set: (1253, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 25
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 78.801843
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.85      0.87      0.86       321
#            1       0.60      0.55      0.57       113
#
#     accuracy                           0.79       434
#    macro avg       0.72      0.71      0.72       434
# weighted avg       0.78      0.79      0.78       434
#
#
# Confusion matrix:
# [[280  41]
#  [ 51  62]]
# --------------------------------
# Train set: (50, 10)
# Validation set: (1252, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 26
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 79.262673
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.84      0.88      0.86       321
#            1       0.62      0.53      0.57       113
#
#     accuracy                           0.79       434
#    macro avg       0.73      0.71      0.72       434
# weighted avg       0.78      0.79      0.79       434
#
#
# Confusion matrix:
# [[284  37]
#  [ 53  60]]
# --------------------------------
# Train set: (51, 10)
# Validation set: (1251, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 27
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 77.880184
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.84      0.86      0.85       321
#            1       0.58      0.54      0.56       113
#
#     accuracy                           0.78       434
#    macro avg       0.71      0.70      0.71       434
# weighted avg       0.77      0.78      0.78       434
#
#
# Confusion matrix:
# [[277  44]
#  [ 52  61]]
# --------------------------------
# Train set: (52, 10)
# Validation set: (1250, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 28
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 79.032258
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.84      0.88      0.86       321
#            1       0.61      0.53      0.57       113
#
#     accuracy                           0.79       434
#    macro avg       0.73      0.71      0.72       434
# weighted avg       0.78      0.79      0.79       434
#
#
# Confusion matrix:
# [[283  38]
#  [ 53  60]]
# --------------------------------
# Train set: (53, 10)
# Validation set: (1249, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 29
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 74.884793
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.85      0.80      0.83       321
#            1       0.52      0.59      0.55       113
#
#     accuracy                           0.75       434
#    macro avg       0.68      0.70      0.69       434
# weighted avg       0.76      0.75      0.75       434
#
#
# Confusion matrix:
# [[258  63]
#  [ 46  67]]
# --------------------------------
# Train set: (54, 10)
# Validation set: (1248, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 30
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 75.345622
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.85      0.80      0.83       321
#            1       0.52      0.61      0.56       113
#
#     accuracy                           0.75       434
#    macro avg       0.69      0.71      0.70       434
# weighted avg       0.77      0.75      0.76       434
#
#
# Confusion matrix:
# [[258  63]
#  [ 44  69]]
# --------------------------------
# Train set: (55, 10)
# Validation set: (1247, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 31
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 74.654378
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.86      0.79      0.82       321
#            1       0.51      0.62      0.56       113
#
#     accuracy                           0.75       434
#    macro avg       0.68      0.71      0.69       434
# weighted avg       0.77      0.75      0.75       434
#
#
# Confusion matrix:
# [[254  67]
#  [ 43  70]]
# --------------------------------
# Train set: (56, 10)
# Validation set: (1246, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 32
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 79.262673
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.86       321
#            1       0.61      0.56      0.58       113
#
#     accuracy                           0.79       434
#    macro avg       0.73      0.72      0.72       434
# weighted avg       0.79      0.79      0.79       434
#
#
# Confusion matrix:
# [[281  40]
#  [ 50  63]]
# --------------------------------
# Train set: (57, 10)
# Validation set: (1245, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 33
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 79.262673
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.86       321
#            1       0.61      0.55      0.58       113
#
#     accuracy                           0.79       434
#    macro avg       0.73      0.71      0.72       434
# weighted avg       0.79      0.79      0.79       434
#
#
# Confusion matrix:
# [[282  39]
#  [ 51  62]]
# --------------------------------
# Train set: (58, 10)
# Validation set: (1244, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 34
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 75.115207
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.85      0.81      0.83       321
#            1       0.52      0.59      0.55       113
#
#     accuracy                           0.75       434
#    macro avg       0.68      0.70      0.69       434
# weighted avg       0.76      0.75      0.76       434
#
#
# Confusion matrix:
# [[259  62]
#  [ 46  67]]
# --------------------------------
# Train set: (59, 10)
# Validation set: (1243, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 35
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 75.345622
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.86      0.79      0.83       321
#            1       0.52      0.64      0.57       113
#
#     accuracy                           0.75       434
#    macro avg       0.69      0.72      0.70       434
# weighted avg       0.77      0.75      0.76       434
#
#
# Confusion matrix:
# [[255  66]
#  [ 41  72]]
# --------------------------------
# Train set: (60, 10)
# Validation set: (1242, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 36
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 81.105991
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.86      0.88      0.87       321
#            1       0.65      0.60      0.62       113
#
#     accuracy                           0.81       434
#    macro avg       0.76      0.74      0.75       434
# weighted avg       0.81      0.81      0.81       434
#
#
# Confusion matrix:
# [[284  37]
#  [ 45  68]]
# --------------------------------
# Train set: (61, 10)
# Validation set: (1241, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 37
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 75.576037
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.86      0.79      0.83       321
#            1       0.53      0.65      0.58       113
#
#     accuracy                           0.76       434
#    macro avg       0.69      0.72      0.70       434
# weighted avg       0.78      0.76      0.76       434
#
#
# Confusion matrix:
# [[255  66]
#  [ 40  73]]
# --------------------------------
# Train set: (62, 10)
# Validation set: (1240, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 38
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 76.267281
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.87      0.80      0.83       321
#            1       0.54      0.65      0.59       113
#
#     accuracy                           0.76       434
#    macro avg       0.70      0.72      0.71       434
# weighted avg       0.78      0.76      0.77       434
#
#
# Confusion matrix:
# [[258  63]
#  [ 40  73]]
# --------------------------------
# Train set: (63, 10)
# Validation set: (1239, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 39
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 76.497696
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.87      0.81      0.84       321
#            1       0.54      0.65      0.59       113
#
#     accuracy                           0.76       434
#    macro avg       0.70      0.73      0.71       434
# weighted avg       0.78      0.76      0.77       434
#
#
# Confusion matrix:
# [[259  62]
#  [ 40  73]]
# --------------------------------
# Train set: (64, 10)
# Validation set: (1238, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 40
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 76.267281
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.86      0.81      0.83       321
#            1       0.54      0.64      0.58       113
#
#     accuracy                           0.76       434
#    macro avg       0.70      0.72      0.71       434
# weighted avg       0.78      0.76      0.77       434
#
#
# Confusion matrix:
# [[259  62]
#  [ 41  72]]
# --------------------------------
# Train set: (65, 10)
# Validation set: (1237, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 41
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 76.497696
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.86      0.81      0.84       321
#            1       0.54      0.64      0.59       113
#
#     accuracy                           0.76       434
#    macro avg       0.70      0.72      0.71       434
# weighted avg       0.78      0.76      0.77       434
#
#
# Confusion matrix:
# [[260  61]
#  [ 41  72]]
# --------------------------------
# Train set: (66, 10)
# Validation set: (1236, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 42
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 75.576037
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.86      0.80      0.83       321
#            1       0.53      0.64      0.58       113
#
#     accuracy                           0.76       434
#    macro avg       0.69      0.72      0.70       434
# weighted avg       0.77      0.76      0.76       434
#
#
# Confusion matrix:
# [[256  65]
#  [ 41  72]]
# --------------------------------
# Train set: (67, 10)
# Validation set: (1235, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 43
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 76.036866
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.87      0.80      0.83       321
#            1       0.53      0.65      0.58       113
#
#     accuracy                           0.76       434
#    macro avg       0.70      0.72      0.71       434
# weighted avg       0.78      0.76      0.77       434
#
#
# Confusion matrix:
# [[257  64]
#  [ 40  73]]
# --------------------------------
# Train set: (68, 10)
# Validation set: (1234, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 44
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 76.036866
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.86      0.80      0.83       321
#            1       0.53      0.64      0.58       113
#
#     accuracy                           0.76       434
#    macro avg       0.70      0.72      0.71       434
# weighted avg       0.78      0.76      0.77       434
#
#
# Confusion matrix:
# [[258  63]
#  [ 41  72]]
# --------------------------------
# Train set: (69, 10)
# Validation set: (1233, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 45
# --------------------------------
# y-test set: (434,)
# Training run in 0.001 s
#
# Accuracy rate is 76.497696
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.87      0.81      0.84       321
#            1       0.54      0.65      0.59       113
#
#     accuracy                           0.76       434
#    macro avg       0.70      0.73      0.71       434
# weighted avg       0.78      0.76      0.77       434
#
#
# Confusion matrix:
# [[259  62]
#  [ 40  73]]
# --------------------------------
# Train set: (70, 10)
# Validation set: (1232, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 46
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 76.267281
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.86      0.81      0.83       321
#            1       0.54      0.64      0.58       113
#
#     accuracy                           0.76       434
#    macro avg       0.70      0.72      0.71       434
# weighted avg       0.78      0.76      0.77       434
#
#
# Confusion matrix:
# [[259  62]
#  [ 41  72]]
# --------------------------------
# Train set: (71, 10)
# Validation set: (1231, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 47
# --------------------------------
# y-test set: (434,)
# Training run in 0.003 s
#
# Accuracy rate is 76.728111
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.86      0.81      0.84       321
#            1       0.55      0.64      0.59       113
#
#     accuracy                           0.77       434
#    macro avg       0.70      0.73      0.71       434
# weighted avg       0.78      0.77      0.77       434
#
#
# Confusion matrix:
# [[261  60]
#  [ 41  72]]
# --------------------------------
# Train set: (72, 10)
# Validation set: (1230, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 48
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 76.728111
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.87      0.81      0.84       321
#            1       0.54      0.65      0.59       113
#
#     accuracy                           0.77       434
#    macro avg       0.71      0.73      0.71       434
# weighted avg       0.78      0.77      0.77       434
#
#
# Confusion matrix:
# [[260  61]
#  [ 40  73]]
# --------------------------------
# Train set: (73, 10)
# Validation set: (1229, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 49
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 75.576037
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.86      0.80      0.83       321
#            1       0.53      0.64      0.58       113
#
#     accuracy                           0.76       434
#    macro avg       0.69      0.72      0.70       434
# weighted avg       0.77      0.76      0.76       434
#
#
# Confusion matrix:
# [[256  65]
#  [ 41  72]]
# --------------------------------
# Train set: (74, 10)
# Validation set: (1228, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 50
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 76.036866
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.86      0.80      0.83       321
#            1       0.53      0.64      0.58       113
#
#     accuracy                           0.76       434
#    macro avg       0.70      0.72      0.71       434
# weighted avg       0.78      0.76      0.77       434
#
#
# Confusion matrix:
# [[258  63]
#  [ 41  72]]
# --------------------------------
# Train set: (75, 10)
# Validation set: (1227, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 51
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 75.345622
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.86      0.79      0.83       321
#            1       0.52      0.64      0.57       113
#
#     accuracy                           0.75       434
#    macro avg       0.69      0.72      0.70       434
# weighted avg       0.77      0.75      0.76       434
#
#
# Confusion matrix:
# [[255  66]
#  [ 41  72]]
# --------------------------------
# Train set: (76, 10)
# Validation set: (1226, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 52
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 75.345622
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.86      0.79      0.83       321
#            1       0.52      0.64      0.57       113
#
#     accuracy                           0.75       434
#    macro avg       0.69      0.72      0.70       434
# weighted avg       0.77      0.75      0.76       434
#
#
# Confusion matrix:
# [[255  66]
#  [ 41  72]]
# --------------------------------
# Train set: (77, 10)
# Validation set: (1225, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 53
# --------------------------------
# y-test set: (434,)
# Training run in 0.003 s
#
# Accuracy rate is 75.806452
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.86      0.80      0.83       321
#            1       0.53      0.64      0.58       113
#
#     accuracy                           0.76       434
#    macro avg       0.70      0.72      0.70       434
# weighted avg       0.78      0.76      0.76       434
#
#
# Confusion matrix:
# [[257  64]
#  [ 41  72]]
# --------------------------------
# Train set: (78, 10)
# Validation set: (1224, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 54
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 75.576037
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.86      0.80      0.83       321
#            1       0.53      0.64      0.58       113
#
#     accuracy                           0.76       434
#    macro avg       0.69      0.72      0.70       434
# weighted avg       0.77      0.76      0.76       434
#
#
# Confusion matrix:
# [[256  65]
#  [ 41  72]]
# --------------------------------
# Train set: (79, 10)
# Validation set: (1223, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 55
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 75.345622
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.86      0.79      0.83       321
#            1       0.52      0.65      0.58       113
#
#     accuracy                           0.75       434
#    macro avg       0.69      0.72      0.70       434
# weighted avg       0.77      0.75      0.76       434
#
#
# Confusion matrix:
# [[254  67]
#  [ 40  73]]
# --------------------------------
# Train set: (80, 10)
# Validation set: (1222, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 56
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 75.345622
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.86      0.79      0.83       321
#            1       0.52      0.64      0.57       113
#
#     accuracy                           0.75       434
#    macro avg       0.69      0.72      0.70       434
# weighted avg       0.77      0.75      0.76       434
#
#
# Confusion matrix:
# [[255  66]
#  [ 41  72]]
# --------------------------------
# Train set: (81, 10)
# Validation set: (1221, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 57
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 75.806452
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.86      0.80      0.83       321
#            1       0.53      0.64      0.58       113
#
#     accuracy                           0.76       434
#    macro avg       0.70      0.72      0.70       434
# weighted avg       0.78      0.76      0.76       434
#
#
# Confusion matrix:
# [[257  64]
#  [ 41  72]]
# --------------------------------
# Train set: (82, 10)
# Validation set: (1220, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 58
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 75.806452
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.86      0.80      0.83       321
#            1       0.53      0.65      0.58       113
#
#     accuracy                           0.76       434
#    macro avg       0.70      0.72      0.71       434
# weighted avg       0.78      0.76      0.77       434
#
#
# Confusion matrix:
# [[256  65]
#  [ 40  73]]
# --------------------------------
# Train set: (83, 10)
# Validation set: (1219, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 59
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 74.884793
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.86      0.79      0.82       321
#            1       0.51      0.64      0.57       113
#
#     accuracy                           0.75       434
#    macro avg       0.69      0.71      0.70       434
# weighted avg       0.77      0.75      0.76       434
#
#
# Confusion matrix:
# [[253  68]
#  [ 41  72]]
# --------------------------------
# Train set: (84, 10)
# Validation set: (1218, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 60
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 75.345622
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.86      0.79      0.83       321
#            1       0.52      0.64      0.57       113
#
#     accuracy                           0.75       434
#    macro avg       0.69      0.72      0.70       434
# weighted avg       0.77      0.75      0.76       434
#
#
# Confusion matrix:
# [[255  66]
#  [ 41  72]]
# --------------------------------
# Train set: (85, 10)
# Validation set: (1217, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 61
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 75.115207
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.86      0.79      0.82       321
#            1       0.52      0.64      0.57       113
#
# ...
#
#
# Confusion matrix:
# [[279  42]
#  [ 50  63]]
# --------------------------------
# Train set: (491, 10)
# Validation set: (811, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 467
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 78.801843
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.85      0.87      0.86       321
#            1       0.60      0.56      0.58       113
#
#     accuracy                           0.79       434
#    macro avg       0.72      0.71      0.72       434
# weighted avg       0.78      0.79      0.79       434
#
#
# Confusion matrix:
# [[279  42]
#  [ 50  63]]
# --------------------------------
# Train set: (492, 10)
# Validation set: (810, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 468
# --------------------------------
# y-test set: (434,)
# Training run in 0.001 s
#
# Accuracy rate is 78.801843
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.85      0.87      0.86       321
#            1       0.60      0.56      0.58       113
#
#     accuracy                           0.79       434
#    macro avg       0.72      0.71      0.72       434
# weighted avg       0.78      0.79      0.79       434
#
#
# Confusion matrix:
# [[279  42]
#  [ 50  63]]
# --------------------------------
# Train set: (493, 10)
# Validation set: (809, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 469
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 78.571429
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.85      0.87      0.86       321
#            1       0.60      0.55      0.57       113
#
#     accuracy                           0.79       434
#    macro avg       0.72      0.71      0.71       434
# weighted avg       0.78      0.79      0.78       434
#
#
# Confusion matrix:
# [[279  42]
#  [ 51  62]]
# --------------------------------
# Train set: (494, 10)
# Validation set: (808, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 470
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 78.801843
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.85      0.87      0.86       321
#            1       0.60      0.56      0.58       113
#
#     accuracy                           0.79       434
#    macro avg       0.72      0.71      0.72       434
# weighted avg       0.78      0.79      0.79       434
#
#
# Confusion matrix:
# [[279  42]
#  [ 50  63]]
# --------------------------------
# Train set: (495, 10)
# Validation set: (807, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 471
# --------------------------------
# y-test set: (434,)
# Training run in 0.004 s
#
# Accuracy rate is 78.801843
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.85      0.87      0.86       321
#            1       0.60      0.56      0.58       113
#
#     accuracy                           0.79       434
#    macro avg       0.72      0.71      0.72       434
# weighted avg       0.78      0.79      0.79       434
#
#
# Confusion matrix:
# [[279  42]
#  [ 50  63]]
# --------------------------------
# Train set: (496, 10)
# Validation set: (806, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 472
# --------------------------------
# y-test set: (434,)
# Training run in 0.001 s
#
# Accuracy rate is 78.571429
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.85      0.87      0.86       321
#            1       0.60      0.55      0.57       113
#
#     accuracy                           0.79       434
#    macro avg       0.72      0.71      0.71       434
# weighted avg       0.78      0.79      0.78       434
#
#
# Confusion matrix:
# [[279  42]
#  [ 51  62]]
# --------------------------------
# Train set: (497, 10)
# Validation set: (805, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 473
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 78.571429
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.85      0.87      0.86       321
#            1       0.60      0.55      0.57       113
#
#     accuracy                           0.79       434
#    macro avg       0.72      0.71      0.71       434
# weighted avg       0.78      0.79      0.78       434
#
#
# Confusion matrix:
# [[279  42]
#  [ 51  62]]
# --------------------------------
# Train set: (498, 10)
# Validation set: (804, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 474
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 78.571429
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.85      0.87      0.86       321
#            1       0.60      0.55      0.57       113
#
#     accuracy                           0.79       434
#    macro avg       0.72      0.71      0.71       434
# weighted avg       0.78      0.79      0.78       434
#
#
# Confusion matrix:
# [[279  42]
#  [ 51  62]]
# --------------------------------
# Train set: (499, 10)
# Validation set: (803, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 475
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 78.571429
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.85      0.87      0.86       321
#            1       0.60      0.55      0.57       113
#
#     accuracy                           0.79       434
#    macro avg       0.72      0.71      0.71       434
# weighted avg       0.78      0.79      0.78       434
#
#
# Confusion matrix:
# [[279  42]
#  [ 51  62]]
# --------------------------------
# Train set: (500, 10)
# Validation set: (802, 10)
# Test set: (434, 10)
# training logistic regression...
# --------------------------------
# Iteration: 476
# --------------------------------
# y-test set: (434,)
# Training run in 0.002 s
#
# Accuracy rate is 78.801843
# Classification report for LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear',
#                    tol=0.1):
#               precision    recall  f1-score   support
#
#            0       0.85      0.87      0.86       321
#            1       0.60      0.56      0.58       113
#
#     accuracy                           0.79       434
#    macro avg       0.72      0.71      0.72       434
# weighted avg       0.78      0.79      0.79       434
#
#
# Confusion matrix:
# [[279  42]
#  [ 50  63]]
# --------------------------------
# accuracies [75.34562211981567, 75.57603686635944, 77.64976958525345, 76.72811059907833, 78.80184331797236, 78.3410138248848, 78.80184331797236, 78.57142857142857, 77.88018433179722, 78.57142857142857, 77.41935483870968, 78.80184331797236, 78.57142857142857, 79.26267281105991, 77.41935483870968, 76.95852534562212, 78.57142857142857, 78.3410138248848, 77.41935483870968, 78.80184331797236, 78.80184331797236, 79.49308755760369, 78.80184331797236, 78.80184331797236, 78.80184331797236, 79.26267281105991, 77.88018433179722, 79.03225806451613, 74.88479262672811, 75.34562211981567, 74.65437788018433, 79.26267281105991, 79.26267281105991, 75.11520737327189, 75.34562211981567, 81.10599078341014, 75.57603686635944, 76.26728110599078, 76.49769585253456, 76.26728110599078, 76.49769585253456, 75.57603686635944, 76.036866359447, 76.036866359447, 76.49769585253456, 76.26728110599078, 76.72811059907833, 76.72811059907833, 75.57603686635944, 76.036866359447, 75.34562211981567, 75.34562211981567, 75.80645161290323, 75.57603686635944, 75.34562211981567, 75.34562211981567, 75.80645161290323, 75.80645161290323, 74.88479262672811, 75.34562211981567, 75.11520737327189, 74.65437788018433, 76.036866359447, 75.57603686635944, 75.11520737327189, 75.11520737327189, 79.72350230414746, 79.95391705069125, 79.72350230414746, 79.95391705069125, 79.49308755760369, 79.26267281105991, 79.95391705069125, 79.95391705069125, 79.95391705069125, 79.72350230414746, 80.18433179723502, 79.95391705069125, 79.95391705069125, 79.49308755760369, 79.49308755760369, 79.49308755760369, 79.03225806451613, 79.03225806451613, 79.49308755760369, 79.95391705069125, 79.49308755760369, 79.49308755760369, 79.95391705069125, 79.49308755760369, 79.95391705069125, 80.4147465437788, 79.95391705069125, 80.18433179723502, 80.64516129032258, 80.4147465437788, 80.87557603686636, 81.10599078341014, 81.10599078341014, 81.10599078341014, 80.64516129032258, 80.64516129032258, 80.4147465437788, 80.4147465437788, 80.4147465437788, 79.95391705069125, 80.4147465437788, 80.4147465437788, 80.4147465437788, 80.4147465437788, 80.4147465437788, 80.87557603686636, 80.64516129032258, 80.18433179723502, 80.18433179723502, 79.95391705069125, 80.64516129032258, 79.95391705069125, 79.95391705069125, 79.95391705069125, 79.95391705069125, 79.72350230414746, 80.18433179723502, 79.95391705069125, 79.95391705069125, 79.95391705069125, 78.80184331797236, 79.26267281105991, 79.72350230414746, 79.49308755760369, 79.49308755760369, 79.26267281105991, 79.95391705069125, 79.72350230414746, 79.95391705069125, 79.95391705069125, 80.4147465437788, 79.72350230414746, 79.72350230414746, 79.72350230414746, 79.49308755760369, 79.03225806451613, 79.26267281105991, 79.26267281105991, 79.26267281105991, 79.03225806451613, 79.26267281105991, 79.03225806451613, 79.03225806451613, 79.03225806451613, 79.03225806451613, 79.03225806451613, 79.49308755760369, 79.03225806451613, 79.26267281105991, 79.03225806451613, 79.03225806451613, 79.49308755760369, 79.26267281105991, 79.03225806451613, 79.03225806451613, 79.03225806451613, 79.26267281105991, 79.26267281105991, 79.26267281105991, 79.03225806451613, 79.26267281105991, 79.49308755760369, 79.03225806451613, 79.72350230414746, 79.49308755760369, 79.26267281105991, 79.26267281105991, 79.26267281105991, 79.26267281105991, 79.49308755760369, 79.49308755760369, 79.26267281105991, 79.49308755760369, 79.49308755760369, 79.72350230414746, 79.49308755760369, 79.49308755760369, 79.72350230414746, 79.72350230414746, 79.49308755760369, 79.26267281105991, 79.49308755760369, 79.49308755760369, 79.49308755760369, 79.26267281105991, 79.72350230414746, 79.72350230414746, 79.72350230414746, 79.72350230414746, 79.95391705069125, 79.95391705069125, 79.72350230414746, 79.49308755760369, 79.49308755760369, 79.49308755760369, 79.26267281105991, 78.80184331797236, 79.03225806451613, 79.26267281105991, 79.26267281105991, 79.49308755760369, 79.49308755760369, 79.26267281105991, 79.26267281105991, 79.26267281105991,  ...
# nonactive_accuracies [64.74654377880185, 63.36405529953917, 62.21198156682027, 63.36405529953917, 64.0552995391705, 62.21198156682027, 64.28571428571429, 56.91244239631337, 64.0552995391705, 63.824884792626726, 64.28571428571429, 59.907834101382484, 64.51612903225806, 56.91244239631337, 61.52073732718893, 64.97695852534562, 62.44239631336406, 59.44700460829493, 64.51612903225806, 64.51612903225806, 64.97695852534562, 62.903225806451616, 56.68202764976959, 63.133640552995395, 64.74654377880185, 60.82949308755761, 59.21658986175116, 64.51612903225806, 64.51612903225806, 63.36405529953917, 62.21198156682027, 63.594470046082954, 62.903225806451616, 64.51612903225806, 61.9815668202765, 60.82949308755761, 58.525345622119815, 62.67281105990783, 63.36405529953917, 64.97695852534562, 64.28571428571429, 64.0552995391705, 64.0552995391705, 63.133640552995395, 60.13824884792627, 64.28571428571429, 63.133640552995395, 64.51612903225806, 62.903225806451616, 61.29032258064516, 64.51612903225806, 63.36405529953917, 59.907834101382484, 59.21658986175116, 64.51612903225806, 63.824884792626726, 63.824884792626726, 64.0552995391705, 61.52073732718893, 63.594470046082954, 57.83410138248848, 59.67741935483871, 61.05990783410138, 63.594470046082954, 63.36405529953917, 61.52073732718893, 63.36405529953917, 57.83410138248848, 63.133640552995395, 60.36866359447005, 64.51612903225806, 62.44239631336406, 63.594470046082954, 61.75115207373272, 64.97695852534562, 61.29032258064516, 57.83410138248848, 63.133640552995395, 63.594470046082954, 63.36405529953917, 58.525345622119815, 63.824884792626726, 63.594470046082954, 64.28571428571429, 64.28571428571429, 62.903225806451616, 64.51612903225806, 64.74654377880185, 64.74654377880185, 61.75115207373272, 61.05990783410138, 64.0552995391705, 64.0552995391705, 63.133640552995395, 63.133640552995395, 63.36405529953917, 55.52995391705069, 62.21198156682027, 64.74654377880185, 61.52073732718893, 64.97695852534562, 64.97695852534562, 63.36405529953917, 63.36405529953917, 64.28571428571429, 54.83870967741935, 64.28571428571429, 63.594470046082954, 56.68202764976959, 62.903225806451616, 63.36405529953917, 54.377880184331794, 55.99078341013824, 64.0552995391705, 63.824884792626726, 56.68202764976959, 58.986175115207374, 63.133640552995395, 64.74654377880185, 64.28571428571429, 64.28571428571429, 64.0552995391705, 59.44700460829493, 64.28571428571429, 62.67281105990783, 54.377880184331794, 64.51612903225806, 59.21658986175116, 58.986175115207374, 63.133640552995395, 63.36405529953917, 62.44239631336406, 64.51612903225806, 63.133640552995395, 59.67741935483871, 60.82949308755761, 63.133640552995395, 58.986175115207374, 61.05990783410138, 61.05990783410138, 61.05990783410138, 63.133640552995395, 57.14285714285714, 64.74654377880185, 63.594470046082954, 64.74654377880185, 64.0552995391705, 63.36405529953917, 61.75115207373272, 63.36405529953917, 64.28571428571429, 63.594470046082954, 64.28571428571429, 54.60829493087558, 63.594470046082954, 63.36405529953917, 58.294930875576036, 58.75576036866359, 64.51612903225806, 57.6036866359447, 64.74654377880185, 64.97695852534562, 63.133640552995395, 63.36405529953917, 62.21198156682027, 63.36405529953917, 61.05990783410138, 56.451612903225815, 64.51612903225806, 64.74654377880185, 62.44239631336406, 64.74654377880185, 64.28571428571429, 63.36405529953917, 61.52073732718893, 62.44239631336406, 59.44700460829493, 59.44700460829493, 55.76036866359447, 62.903225806451616, 62.903225806451616, 63.36405529953917, 64.0552995391705, 62.903225806451616, 56.22119815668203, 63.133640552995395, 63.824884792626726, 63.824884792626726, 63.824884792626726, 63.36405529953917, 63.594470046082954, 63.133640552995395, 64.74654377880185, 64.0552995391705, 64.51612903225806, 64.51612903225806, 63.133640552995395, 64.97695852534562, 56.22119815668203, 61.52073732718893, 64.0552995391705, 64.51612903225806, 54.377880184331794, 59.21658986175116, 61.75115207373272, 64.74654377880185, 61.05990783410138, 63.13 ...
