# %%
print(__doc__)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from matplotlib.lines import Line2D
import glob
import os
from scipy import stats
pd.options.display.float_format = "{:.4f}".format
pd.set_option("display.max_rows", None, "display.max_columns", None)
# Out:
# Automatically created module for IPython interactive environment

# %%
path = r'/Users/wenxuanhuang/Documents/Repo/Active-Learning-Performance-Benchmarking/result_log/Uniterative_test_200/**/'
all_files = sorted(glob.glob(os.path.join(path, "*.csv")))

# print(all_files[0])

# min_abs = []
# idx_min_abs = []
# min_diff = []
# idx_min_diff = []
end_ur_fairness = []
end_ur_accuracies = []
end_rs_fairness = []
end_rs_accuracies = []
end_nonal_fairness = []
end_nonal_accuracies = []

for f in all_files:
    df = pd.read_csv(f)
    df = df.rename(columns={"# x_axis": "axis", " ur_accuracies": "ur_accuracies", " ur_fairness": "ur_fairness", " rs_accuracies": "rs_accuracies", " rs_fairness": "rs_fairness", " nonal_accuracies": "nonal_accuracies", " nonal_fairness": "nonal_fairness"})
    # min_abs = np.append(min_abs, df['ur_fairness'].min())
    # # print(min_abs)
    # idx_min_abs = np.append(idx_min_abs, df['ur_fairness'].idxmin())
    # # print(idx_min_abs)
    # df_diff = df.diff()
    # min_diff = np.append(min_diff, df_diff['ur_fairness'].min())
    # # print(min_diff)
    # idx_min_diff = np.append(idx_min_diff, df_diff['ur_fairness'].idxmin())
    # # print(idx_min_diff)
    end_df = df.iloc[[-1]]
    end_ur_fairness = np.append(end_ur_fairness, end_df['ur_fairness'])
    end_ur_accuracies = np.append(end_ur_accuracies, end_df['ur_accuracies'])
    end_rs_fairness = np.append(end_rs_fairness, end_df['rs_fairness'])
    end_rs_accuracies = np.append(end_rs_accuracies, end_df['rs_accuracies'])
    end_nonal_fairness = np.append(end_nonal_fairness, end_df['nonal_fairness'])
    end_nonal_accuracies = np.append(end_nonal_accuracies, end_df['nonal_accuracies'])

# plt.hist(end_ur_fairness, color = 'red', edgecolor = 'black', bins = 30)
# plt.hist(end_rs_fairness, color = 'green', edgecolor = 'black', bins = 50)
# plt.hist(end_nonal_fairness, color = 'blue', edgecolor = 'black', bins = 20)
# plt.show()

# print(end_rs_fairness)

# print("The average nonal accuracy is", end_nonal_accuracies.shape)
# print("The average nonal accuracy is", format(np.average(end_nonal_accuracies), ".3f"))
# print("The average rs accuracy is", format(np.average(end_rs_accuracies), ".3f"))
# print("The average mc accuracy is", format(np.average(end_ur_accuracies), ".3f"))
# print("The average nonal fairness is", format(np.average(end_nonal_fairness), ".5f"))
# print("The average rs fairness is", format(np.average(end_rs_fairness), ".5f"))
# print("The average mc fairness is", format(np.average(end_ur_fairness), ".5f"))

# stats.ttest_rel(end_rs_fairness, end_ur_fairness)
# stats.probplot(end_ur_fairness, dist="norm", plot=plt) # test whether normally distributed
# stats.wilcoxon(end_ur_fairness, end_rs_fairness)
# Out:
# [0.017983 0.011807 0.012866 0.013753 0.014493 0.015563 0.01766  0.011874
#  0.013115 0.013387 0.018952 0.01954  0.020096 0.021189 0.006516 0.013582
#  0.01562  0.025124 0.014511 0.002681 0.007813 0.01346  0.005027 0.016024
#  0.013907 0.017462 0.013062 0.014987 0.014045 0.011021 0.020787 0.008674
#  0.01211  0.013791 0.013357 0.009782 0.018733 0.016195 0.011011 0.015918
#  0.015872 0.021299 0.017567 0.013151 0.016024 0.012253 0.019942 0.019822
#  0.01612  0.018394 0.025326 0.009534 0.016926 0.001197 0.009652 0.017677
#  0.016651 0.016223 0.005095 0.011804 0.025018 0.020289 0.01826  0.014178
#  0.014904 0.01894  0.009035 0.007617 0.02227  0.006421 0.011198 0.020248
#  0.006266 0.012936 0.026208 0.022035 0.001376 0.014225 0.017938 0.015554
#  0.01063  0.005863 0.025462 0.016024 0.006035 0.010782 0.015303 0.020094
#  0.013515 0.015505 0.020294 0.015474 0.027056 0.028179 0.019315 0.021324
#  0.007025 0.026675 0.008356 0.013443 0.014237 0.021463 0.02095  0.014268
#  0.026355 0.026682 0.019418 0.011345 0.025075 0.023668 0.022948 0.016708
#  0.022297 0.021354 0.013433 0.015014 0.01874  0.019074 0.011218 0.021693
#  0.020174 0.02048  0.017523 0.016952 0.020636 0.010264 0.013777 0.02385
#  0.020864 0.015916 0.017071 0.020185 0.018287 0.017126 0.015883 0.018484
#  0.011362 0.022609 0.013682 0.022607 0.014371 0.021969 0.014838 0.017867
#  0.020331 0.022856 0.009166 0.024705 0.018398 0.030648 0.022025 0.021283
#  0.012906 0.024761 0.02175  0.021883 0.016951 0.013731 0.013468 0.009807
#  0.024968 0.018806 0.015353 0.014316 0.018573 0.012424 0.026577 0.017801
#  0.016841 0.027614 0.023171 0.018924 0.019289 0.020442 0.013524 0.015312
#  0.020877 0.015729 0.014706 0.025401 0.020537 0.016927 0.015607 0.017397
#  0.010118 0.009302 0.015475 0.020513 0.014446 0.009302 0.008246 0.019985
#  0.012593 0.024039 0.020296 0.019877 0.01164  0.014044 0.016539 0.023068
#  0.020592 0.012608 0.014316 0.01687  0.0225   0.006479 0.029427 0.022358
#  0.015329 0.01556  0.015286 0.01714  0.011445 0.014573 0.012241 0.001005
#  0.006327 0.017142 0.015487 0.015406 0.00737  0.016626 0.012517 0.01935
#  0.021379 0.010561 0.015702 0.01523  0.020671 0.004322 0.023431 0.015008
#  0.015581 0.022204 0.020762 0.009708 0.015268 0.021078 0.020414 0.022029
#  0.027587 0.010593 0.008404 0.018073 0.012908 0.03346  0.024876 0.01062
#  0.018565 0.020161 0.013806 0.013211 0.021302 0.019844 0.006924 0.019865
#  0.01611  0.027285 0.018586 0.014669 0.028411 0.015915 0.015743 0.017903
#  0.021105 0.013081 0.020027 0.029069 0.012539 0.02138  0.017593 0.014215
#  0.022013 0.019967 0.007441 0.013463 0.014367 0.024977 0.014086 0.015554
#  0.022497 0.017018 0.018676 0.012783 0.019752 0.015214 0.020094 0.020512
#  0.026549 0.017175 0.020753 0.014215 0.014742 0.004003 0.017352 0.015133
#  0.028167 0.013399 0.018048 0.015671 0.017219 0.014681 0.024875 0.019457
#  0.023029 0.016771 0.017778 0.022896 0.027169 0.018566 0.016769 0.019903
#  0.012423 0.017373 0.013199 0.008541 0.024286 0.015885 0.010462 0.014382
#  0.011754 0.024374 0.014838 0.016618 0.021936 0.02076  0.012115 0.016891
#  0.02302  0.012741 0.018035 0.017434 0.025738 0.014022 0.009773 0.017162
#  0.025018 0.020594 0.005006 0.020738 0.014837 0.023329 0.019393 0.021343
#  0.005506 0.019915 0.012738 0.021529 0.024777 0.016329 0.020161 0.020598
#  0.016036 0.013997 0.014282 0.018286 0.014293 0.025581 0.011381 0.014767
#  0.013573 0.019892 0.018955 0.005701 0.013729 0.013862 0.022036 0.019087
#  0.025974 0.012904 0.015923 0.020249 0.02076  0.020875 0.015416 0.020455
#  0.019283 0.018215 0.009774 0.021861 0.019459 0.032371 0.020418 0.015702
#  0.010973 0.018987 0.016105 0.023737 0.026415 0.014481 0.014255 0.013632
#  0.022966 0.024576 0.011672 0.018444 0.018883 0.020957 0.023407 0.020414
#  0.024283 0.019235 0.019547 0.0155   0.0288   0.017843 0.018968 0.020827
#  0.01588  0.012279 0.018766 0.02783  0.016918 0.018525 0.023061 0.025277
#  0.020053 0.023693 0.017224 0.016588 0.024183 0.023001 0.016809 0.016195
#  0.015598 0.031934 0.024981 0.020106 0.022354 0.012511 0.023989 0.019441
#  0.00844  0.020214 0.025551 0.01996  0.013093 0.020418 0.022558 0.023833
#  0.015046 0.013394 0.017198 0.019906 0.014895 0.018035 0.01808  0.021253
#  0.015195 0.013757 0.01695  0.024636 0.024206 0.007115 0.022169 0.012956
#  0.010523 0.017462 0.010984 0.009958 0.018177 0.021541 0.019563 0.018216
#  0.008034 0.013179 0.024261 0.025225 0.025586 0.007889 0.015634 0.019406
#  0.015088 0.020198 0.019017 0.029707 0.023218 0.015069 0.012403 0.011771
#  0.011112 0.020776 0.013795 0.007472 0.024835 0.01118  0.019892 0.015538
#  0.011418 0.013568 0.014714 0.018723 0.014572 0.018414 0.02222  0.009454
#  0.010002 0.02125  0.019649 0.012575]
