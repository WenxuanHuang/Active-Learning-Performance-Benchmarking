# %%
print(__doc__)
import math

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.utils import check_random_state
from sklearn.model_selection import KFold
from sklearn import preprocessing
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_roc_curve
from sklearn.metrics import mutual_info_score

from sklearn.linear_model import LogisticRegression
import statsmodels.api as sm

# from ace import model
# from ace import ace
import ace.model
import ace.ace

pd.options.display.float_format = "{:.1f}".format
# Out:
# Automatically created module for IPython interactive environment

# %%
def retrieve_data_adult():

    # np.random.seed(42)
    df = pd.read_csv("https://raw.githubusercontent.com/WenxuanHuang/Maximal-Correlation-Unfairness-Reduction/main/IBM_adult.csv", sep=',')
    df_X = df.iloc[:500, 1:-2]
    # print(df_X.head())
    data_col = df.columns
    


    
    df_y = df['Target'][:500]
    df_X = df_X.values
    df_y = df_y.values.astype('int64')
    df_b = df['Gender'][:500].values
    
    # print(df_X.shape)
    # print(df_y.shape)
    # print(df_b.shape)
    
    return (df_X, df_y, df_b)

# %%
def maximal_correlation_transform(ace_model, x, y):
    
    ace_model.build_model_from_xy(x, y)
    X_transformed = ace_model.ace.x_transforms
    y_transformed = ace_model.ace.y_transform
    
    return X_transformed, y_transformed

# %%
(X,y,b) = retrieve_data_adult()

# %%
Xb_ace = ace.model.Model()
Xy_ace = ace.model.Model()

X_Xb_Mc, b_Xb_Mc = maximal_correlation_transform(Xb_ace, X.T.tolist(), b.tolist())
X_Xy_Mc, y_Xy_Mc = maximal_correlation_transform(Xy_ace, X.T.tolist(), y.tolist())
# Out:
# * Starting outer iteration 000. Current err =  1.00000E+00
#   Starting inner iteration 000. Current err =  1.00000E+00
#   Starting inner iteration 001. Current err =  3.81973E-01
#   Starting inner iteration 002. Current err =  3.32433E-01
#   Starting inner iteration 003. Current err =  3.23092E-01
#   Starting inner iteration 004. Current err =  3.18747E-01
#   Starting inner iteration 005. Current err =  3.16028E-01
#   Starting inner iteration 006. Current err =  3.15104E-01
#   Starting inner iteration 007. Current err =  3.14686E-01
#   Starting inner iteration 008. Current err =  3.14485E-01
#   Starting inner iteration 009. Current err =  3.14298E-01
#   Starting inner iteration 010. Current err =  3.14027E-01
#   Starting inner iteration 011. Current err =  3.13906E-01
#   Starting inner iteration 012. Current err =  3.13504E-01
#   Starting inner iteration 013. Current err =  3.13017E-01
#   Starting inner iteration 014. Current err =  3.12306E-01
#   Starting inner iteration 015. Current err =  3.11402E-01
#   Starting inner iteration 016. Current err =  3.10878E-01
#   Starting inner iteration 017. Current err =  3.10563E-01
#   Starting inner iteration 018. Current err =  3.10171E-01
#   Starting inner iteration 019. Current err =  3.09899E-01
#   Starting inner iteration 020. Current err =  3.09678E-01
#   Starting inner iteration 021. Current err =  3.09474E-01
#   Starting inner iteration 022. Current err =  3.09355E-01
#   Starting inner iteration 023. Current err =  3.09264E-01
#   Starting inner iteration 024. Current err =  3.09150E-01
#   Starting inner iteration 025. Current err =  3.09026E-01
#   Starting inner iteration 026. Current err =  3.08912E-01
#   Starting inner iteration 027. Current err =  3.08788E-01
#   Starting inner iteration 028. Current err =  3.08774E-01
# * Starting outer iteration 001. Current err =  3.94385E-01
#   Starting inner iteration 000. Current err =  3.94385E-01
#   Starting inner iteration 001. Current err =  2.89465E-01
#   Starting inner iteration 002. Current err =  2.83630E-01
#   Starting inner iteration 003. Current err =  2.83168E-01
#   Starting inner iteration 004. Current err =  2.82173E-01
#   Starting inner iteration 005. Current err =  2.81041E-01
#   Starting inner iteration 006. Current err =  2.79984E-01
#   Starting inner iteration 007. Current err =  2.79337E-01
#   Starting inner iteration 008. Current err =  2.78901E-01
#   Starting inner iteration 009. Current err =  2.78604E-01
#   Starting inner iteration 010. Current err =  2.78341E-01
#   Starting inner iteration 011. Current err =  2.78054E-01
#   Starting inner iteration 012. Current err =  2.77806E-01
#   Starting inner iteration 013. Current err =  2.77573E-01
#   Starting inner iteration 014. Current err =  2.77363E-01
#   Starting inner iteration 015. Current err =  2.77220E-01
#   Starting inner iteration 016. Current err =  2.77084E-01
#   Starting inner iteration 017. Current err =  2.76971E-01
#   Starting inner iteration 018. Current err =  2.76891E-01
#   Starting inner iteration 019. Current err =  2.76862E-01
#   Starting inner iteration 020. Current err =  2.76860E-01
# * Starting outer iteration 002. Current err =  3.44164E-01
#   Starting inner iteration 000. Current err =  3.44164E-01
#   Starting inner iteration 001. Current err =  1.60822E-01
#   Starting inner iteration 002. Current err =  1.53415E-01
#   Starting inner iteration 003. Current err =  1.51058E-01
#   Starting inner iteration 004. Current err =  1.48612E-01
#   Starting inner iteration 005. Current err =  1.47643E-01
#   Starting inner iteration 006. Current err =  1.46801E-01
#   Starting inner iteration 007. Current err =  1.46069E-01
#   Starting inner iteration 008. Current err =  1.45211E-01
#   Starting inner iteration 009. Current err =  1.44724E-01
#   Starting inner iteration 010. Current err =  1.44352E-01
#   Starting inner iteration 011. Current err =  1.44039E-01
#   Starting inner iteration 012. Current err =  1.43775E-01
#   Starting inner iteration 013. Current err =  1.43542E-01
#   Starting inner iteration 014. Current err =  1.43523E-01
#   Starting inner iteration 015. Current err =  1.43499E-01
#   Starting inner iteration 016. Current err =  1.43470E-01
# * Starting outer iteration 003. Current err =  1.69726E-01
#   Starting inner iteration 000. Current err =  1.69726E-01
#   Starting inner iteration 001. Current err =  7.92420E-02
#   Starting inner iteration 002. Current err =  7.43642E-02
#   Starting inner iteration 003. Current err =  7.25959E-02
#   Starting inner iteration 004. Current err =  7.15080E-02
#   Starting inner iteration 005. Current err =  7.07929E-02
#   Starting inner iteration 006. Current err =  7.05827E-02
#   Starting inner iteration 007. Current err =  7.01899E-02
#   Starting inner iteration 008. Current err =  6.98241E-02
#   Starting inner iteration 009. Current err =  6.95130E-02
#   Starting inner iteration 010. Current err =  6.92514E-02
#   Starting inner iteration 011. Current err =  6.90372E-02
#   Starting inner iteration 012. Current err =  6.89093E-02
#   Starting inner iteration 013. Current err =  6.88164E-02
#   Starting inner iteration 014. Current err =  6.87550E-02
#   Starting inner iteration 015. Current err =  6.87433E-02
# * Starting outer iteration 004. Current err =  9.38043E-02
#   Starting inner iteration 000. Current err =  9.38043E-02
#   Starting inner iteration 001. Current err =  7.02321E-02
# * Starting outer iteration 005. Current err =  8.45016E-02
#   Starting inner iteration 000. Current err =  8.45016E-02
#   Starting inner iteration 001. Current err =  7.69452E-02
#   Starting inner iteration 002. Current err =  7.57682E-02
#   Starting inner iteration 003. Current err =  7.52993E-02
#   Starting inner iteration 004. Current err =  7.50581E-02
#   Starting inner iteration 005. Current err =  7.49603E-02
#   Starting inner iteration 006. Current err =  7.49306E-02
#   Starting inner iteration 007. Current err =  7.48445E-02
#   Starting inner iteration 008. Current err =  7.47795E-02
#   Starting inner iteration 009. Current err =  7.47061E-02
#   Starting inner iteration 010. Current err =  7.46391E-02
#   Starting inner iteration 011. Current err =  7.45999E-02
#   Starting inner iteration 012. Current err =  7.45719E-02
#   Starting inner iteration 013. Current err =  7.45683E-02
# * Starting outer iteration 006. Current err =  8.18148E-02
#   Starting inner iteration 000. Current err =  8.18148E-02
#   Starting inner iteration 001. Current err =  7.75559E-02
#   Starting inner iteration 002. Current err =  7.72244E-02
#   Starting inner iteration 003. Current err =  7.72138E-02
# * Starting outer iteration 007. Current err =  8.14161E-02
#   Starting inner iteration 000. Current err =  8.14161E-02
#   Starting inner iteration 001. Current err =  7.86323E-02
#   Starting inner iteration 002. Current err =  7.83947E-02
#   Starting inner iteration 003. Current err =  7.83550E-02
#   Starting inner iteration 004. Current err =  7.83389E-02
#   Starting inner iteration 005. Current err =  7.83349E-02
#   Starting inner iteration 006. Current err =  7.83150E-02
#   Starting inner iteration 007. Current err =  7.83001E-02
#   Starting inner iteration 008. Current err =  7.82770E-02
#   Starting inner iteration 009. Current err =  7.82524E-02
#   Starting inner iteration 010. Current err =  7.82513E-02
#   Starting inner iteration 011. Current err =  7.82338E-02
#   Starting inner iteration 012. Current err =  7.82211E-02
#   Starting inner iteration 013. Current err =  7.82134E-02
#   Starting inner iteration 014. Current err =  7.82095E-02
# * Starting outer iteration 008. Current err =  8.09964E-02
#   Starting inner iteration 000. Current err =  8.09964E-02
#   Starting inner iteration 001. Current err =  7.87678E-02
#   Starting inner iteration 002. Current err =  7.86260E-02
#   Starting inner iteration 003. Current err =  7.85521E-02
# * Starting outer iteration 009. Current err =  8.06500E-02
#   Starting inner iteration 000. Current err =  8.06500E-02
#   Starting inner iteration 001. Current err =  7.91274E-02
#   Starting inner iteration 002. Current err =  7.90971E-02
# * Starting outer iteration 000. Current err =  1.00000E+00
#   Starting inner iteration 000. Current err =  1.00000E+00
#   Starting inner iteration 001. Current err =  4.40378E-01
#   Starting inner iteration 002. Current err =  4.15875E-01
#   Starting inner iteration 003. Current err =  4.09540E-01
#   Starting inner iteration 004. Current err =  4.07685E-01
#   Starting inner iteration 005. Current err =  4.06948E-01
#   Starting inner iteration 006. Current err =  4.06607E-01
#   Starting inner iteration 007. Current err =  4.06444E-01
#   Starting inner iteration 008. Current err =  4.06332E-01
#   Starting inner iteration 009. Current err =  4.06203E-01
#   Starting inner iteration 010. Current err =  4.06092E-01
#   Starting inner iteration 011. Current err =  4.05977E-01
#   Starting inner iteration 012. Current err =  4.05825E-01
#   Starting inner iteration 013. Current err =  4.05663E-01
#   Starting inner iteration 014. Current err =  4.05452E-01
#   Starting inner iteration 015. Current err =  4.05306E-01
#   Starting inner iteration 016. Current err =  4.05145E-01
#   Starting inner iteration 017. Current err =  4.04989E-01
#   Starting inner iteration 018. Current err =  4.04830E-01
#   Starting inner iteration 019. Current err =  4.04697E-01
#   Starting inner iteration 020. Current err =  4.04600E-01
#   Starting inner iteration 021. Current err =  4.04519E-01
#   Starting inner iteration 022. Current err =  4.04447E-01
#   Starting inner iteration 023. Current err =  4.04412E-01
#   Starting inner iteration 024. Current err =  4.04396E-01
# * Starting outer iteration 001. Current err =  3.99382E-01
#   Starting inner iteration 000. Current err =  3.99382E-01
#   Starting inner iteration 001. Current err =  3.87208E-01
# * Starting outer iteration 002. Current err =  3.78219E-01
#   Starting inner iteration 000. Current err =  3.78219E-01
#   Starting inner iteration 001. Current err =  3.68906E-01
# * Starting outer iteration 003. Current err =  3.55935E-01
#   Starting inner iteration 000. Current err =  3.55935E-01
#   Starting inner iteration 001. Current err =  3.48955E-01
# * Starting outer iteration 004. Current err =  3.34141E-01
#   Starting inner iteration 000. Current err =  3.34141E-01
#   Starting inner iteration 001. Current err =  3.29812E-01
# * Starting outer iteration 005. Current err =  3.15595E-01
#   Starting inner iteration 000. Current err =  3.15595E-01
#   Starting inner iteration 001. Current err =  3.13133E-01
# * Starting outer iteration 006. Current err =  3.01465E-01
#   Starting inner iteration 000. Current err =  3.01465E-01
#   Starting inner iteration 001. Current err =  3.00021E-01
# * Starting outer iteration 007. Current err =  2.91460E-01
#   Starting inner iteration 000. Current err =  2.91460E-01
#   Starting inner iteration 001. Current err =  2.90767E-01
#   Starting inner iteration 002. Current err =  2.90586E-01
#   Starting inner iteration 003. Current err =  2.90244E-01
#   Starting inner iteration 004. Current err =  2.89983E-01
#   Starting inner iteration 005. Current err =  2.89711E-01
#   Starting inner iteration 006. Current err =  2.89445E-01
#   Starting inner iteration 007. Current err =  2.89175E-01
#   Starting inner iteration 008. Current err =  2.88941E-01
#   Starting inner iteration 009. Current err =  2.88715E-01
#   Starting inner iteration 010. Current err =  2.88460E-01
#   Starting inner iteration 011. Current err =  2.88324E-01
#   Starting inner iteration 012. Current err =  2.88186E-01
#   Starting inner iteration 013. Current err =  2.88107E-01
#   Starting inner iteration 014. Current err =  2.88037E-01
#   Starting inner iteration 015. Current err =  2.88036E-01
#   Starting inner iteration 016. Current err =  2.88019E-01
#   Starting inner iteration 017. Current err =  2.88009E-01
# * Starting outer iteration 008. Current err =  2.84903E-01
#   Starting inner iteration 000. Current err =  2.84903E-01
#   Starting inner iteration 001. Current err =  2.83683E-01
# * Starting outer iteration 009. Current err =  2.82755E-01
#   Starting inner iteration 000. Current err =  2.82755E-01
#   Starting inner iteration 001. Current err =  2.81452E-01
# * Starting outer iteration 010. Current err =  2.82528E-01
#   Starting inner iteration 000. Current err =  2.82528E-01
#   Starting inner iteration 001. Current err =  2.81024E-01
#   Starting inner iteration 002. Current err =  2.81009E-01
#   Starting inner iteration 003. Current err =  2.80965E-01
#   Starting inner iteration 004. Current err =  2.80958E-01
#   Starting inner iteration 005. Current err =  2.80944E-01
#   Starting inner iteration 006. Current err =  2.80933E-01
#   Starting inner iteration 007. Current err =  2.80896E-01
#   Starting inner iteration 008. Current err =  2.80888E-01
#   Starting inner iteration 009. Current err =  2.80881E-01
#   Starting inner iteration 010. Current err =  2.80868E-01
#   Starting inner iteration 011. Current err =  2.80850E-01
#   Starting inner iteration 012. Current err =  2.80817E-01
#   Starting inner iteration 013. Current err =  2.80805E-01
#   Starting inner iteration 014. Current err =  2.80782E-01
#   Starting inner iteration 015. Current err =  2.80750E-01
#   Starting inner iteration 016. Current err =  2.80692E-01
#   Starting inner iteration 017. Current err =  2.80641E-01
#   Starting inner iteration 018. Current err =  2.80567E-01
#   Starting inner iteration 019. Current err =  2.80516E-01
#   Starting inner iteration 020. Current err =  2.80455E-01
#   Starting inner iteration 021. Current err =  2.80390E-01
#   Starting inner iteration 022. Current err =  2.80363E-01
#   Starting inner iteration 023. Current err =  2.80313E-01
#   Starting inner iteration 024. Current err =  2.80273E-01
#   Starting inner iteration 025. Current err =  2.80223E-01
#   Starting inner iteration 026. Current err =  2.80191E-01
#   Starting inner iteration 027. Current err =  2.80164E-01
#   Starting inner iteration 028. Current err =  2.80145E-01
#   Starting inner iteration 029. Current err =  2.80125E-01
#   Starting inner iteration 030. Current err =  2.80107E-01
#   Starting inner iteration 031. Current err =  2.80092E-01

# %%
X_Xy_res = pd.DataFrame(data=np.array(X_Xy_Mc).T)
X_Xy_res.to_csv('X_Xy_Mc_adult.csv',sep=',',index=False)

y_Xy_res = pd.DataFrame(data=np.array(y_Xy_Mc).T)
y_Xy_res.to_csv('y_Xy_Mc_adult.csv',sep=',',index=False)

X_Xb_res = pd.DataFrame(data=np.array(X_Xb_Mc).T)
X_Xb_res.to_csv('X_Xb_Mc_adult.csv',sep=',',index=False)

b_Xb_res = pd.DataFrame(data=np.array(b_Xb_Mc).T)
b_Xb_res.to_csv('b_Xb_Mc_adult.csv',sep=',',index=False)
