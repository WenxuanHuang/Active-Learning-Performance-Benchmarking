# %%
print(__doc__)

import os
import time
import json
import pickle
import math
import random

import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
from scipy.special import expit
from scipy import stats
from pylab import rcParams
import mplcursors

from sklearn.datasets import load_iris
from sklearn.datasets import load_digits

from sklearn.utils import check_random_state
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import RFE
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler

from sklearn import linear_model
from sklearn import neighbors
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso
from sklearn.svm import LinearSVC, SVC
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.utils import check_random_state
from sklearn.metrics import accuracy_score
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from sklearn.naive_bayes import GaussianNB

from sklearn import metrics
from sklearn.metrics import pairwise_distances_argmin_min
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score


# pd.options.display.max_rows = 20
pd.options.display.float_format = "{:.1f}".format
# Out:
# Automatically created module for IPython interactive environment

# %%
def fetch_data_corona():
    data = pd.read_csv("https://raw.githubusercontent.com/WenxuanHuang/ML-for-COVID-19-dataset/main/all_training.csv", sep=',')
    # Column selection
    df = data.iloc[:,np.r_[3:34]].copy()
    # define row and column index
    col = df.columns
    row = [i for i in range(df.shape[0])]
    # define imputer
    imputer = IterativeImputer(estimator=linear_model.BayesianRidge(), n_nearest_features=None, imputation_order='ascending')
    # fit on the dataset
    imputer.fit(df)
    # transform the dataset
    df_imputed = imputer.transform(df)
    # convert back to pandas dataframe and rename back to df_normalized
    df = pd.DataFrame(data=df_imputed, index=row, columns=col)
    X = df
    y = data.target    
    # # Recursive feature elimination
    # rdmreg = RandomForestClassifier(n_estimators=100)
    # # Define the method
    # rfe = RFE(estimator=rdmreg, n_features_to_select=10)
    # # Fit the model
    # rfe = rfe.fit(X, y.values.ravel())
    # print(rfe.support_)
    # # Drop columns that failed RFE test
    # col = df.columns[rfe.support_]
    # X = X[col]
    X = X.to_numpy()
    print ('df:', X.shape, y.shape)
    return (X, y)

# %%
def fetch_data_iris():
    iris = load_iris()
    X = iris.data.astype('float64')
    y = iris.target
    # print ('Dataset : ', X.shape, y.shape)
    return (X, y)

def fetch_data_mnist():
    mnist = load_digits()
    X = mnist.data.astype('float64')
    y = mnist.target
    # print ('Dataset : ', X.shape, y.shape)
    return (X, y)

# %%
class BaseModel(object):

    def __init__(self):
        pass

    def fit_predict(self):
        pass


class SvmModel(BaseModel):

    model_type = 'Support Vector Machine with linear Kernel'
    def fit_predict(self, X_train, y_train, X_val, X_test):
        print ('training svm...')
        self.classifier = SVC(
            kernel='linear', 
            probability=True
            )
        self.classifier.fit(X_train, y_train)
        self.test_y_predicted = self.classifier.predict(X_test)
        self.val_y_predicted = self.classifier.predict(X_val)
        return (X_train, X_val, X_test, self.val_y_predicted,
                self.test_y_predicted)

class LogModel(BaseModel):

    model_type = 'Logistic Regression' 
    def fit_predict(self, X_train, y_train, X_val, X_test):
        # print ('training logistic regression...')
        train_samples = X_train.shape[0]
        self.classifier = LogisticRegression(
            # C=50. / train_samples,
            # penalty='l1',
            solver='newton-cg',
            tol=0.1
            )
        self.classifier.fit(X_train, y_train)
        self.test_y_predicted = self.classifier.predict(X_test)
        self.val_y_predicted = self.classifier.predict(X_val)
        return (X_train, X_val, X_test, self.val_y_predicted,
                self.test_y_predicted)

class RfModel(BaseModel):

    model_type = 'Random Forest'
    def fit_predict(self, X_train, y_train, X_val, X_test):
        print ('training random forest...')
        self.classifier = RandomForestClassifier(
            n_jobs=-1
            )
        self.classifier.fit(X_train, y_train)
        self.test_y_predicted = self.classifier.predict(X_test)
        self.val_y_predicted = self.classifier.predict(X_val)
        return (X_train, X_val, X_test, self.val_y_predicted, self.test_y_predicted)

# %%
class TrainModel:

    def __init__(self, model_object):        
        self.accuracies = []
        self.model_object = model_object()        

    def print_model_type(self):
        print (self.model_object.model_type)

    # we train normally and use the probabilities to select the most uncertain samples
    def train(self, X_train, y_train, X_val, X_test):
        print ('Train set:', X_train.shape)
        print ('Validation set:', X_val.shape)
        print ('Test set:', X_test.shape)
        t0 = time.time()
        (X_train, X_val, X_test, self.val_y_predicted,
         self.test_y_predicted) = \
            self.model_object.fit_predict(X_train, y_train, X_val, X_test)
        self.run_time = time.time() - t0
        return (X_train, X_val, X_test)

    # we want accuracy only for the test set
    def get_test_accuracy(self, i, y_test):
        classif_rate = np.mean(self.test_y_predicted.ravel() == y_test.ravel()) * 100
        self.accuracies.append(classif_rate)               
        print('--------------------------------')
        print('Iteration:',i)
        # print('--------------------------------')
        # print('y-test set:',y_test.shape)
        # print('Training run in %.3f s' % self.run_time,'\n')
        print("Accuracy rate is %f " % (classif_rate))    
        # print("Classification report for %s:\n%s\n" % (self.model_object.classifier, metrics.classification_report(y_test, self.test_y_predicted)))
        # print("Confusion matrix:\n%s" % metrics.confusion_matrix(y_test, self.test_y_predicted))
        print('--------------------------------')

# %%
class Normalize(object):
    
    def normalize(self, X_train, X_val, X_test):
        self.scaler = RobustScaler()
        X_train = self.scaler.fit_transform(X_train)
        X_val   = self.scaler.transform(X_val)
        X_test  = self.scaler.transform(X_test)
        return (X_train, X_val, X_test) 
    
    def inverse(self, X_train, X_val, X_test):
        X_train = self.scaler.inverse_transform(X_train)
        X_val   = self.scaler.inverse_transform(X_val)
        X_test  = self.scaler.inverse_transform(X_test)
        return (X_train, X_val, X_test)

# %%
def get_random_samples(initial_samples, X_train_full, y_train_full):

    permutation = np.random.choice(len(X_train_full),initial_samples,replace=False)
    X_train = X_train_full[permutation]
    y_train = y_train_full[permutation]
    X_train = X_train.reshape((X_train.shape[0], -1))

    return (permutation, X_train, y_train)

# %%
def log_loss(labels, probs):

    eps = np.finfo(probs.dtype).eps
    probs = np.clip(probs, eps, 1 - eps)
    loss = 0

    for i in range(len(probs)):
        for prob in probs[i]:
            loss -= (labels[i]*np.log(prob))
 
    ll = loss/(len(probs)*1.)

    return ll

# %%
def mse_loss(labels, preds):
    loss = 0

    for i in range(len(labels)):
        loss += ((labels[i] - preds[i]) ** 2)

    return loss/len(labels)

# %%
class TheAlgorithm(object):

    accuracies = []

    def __init__(self, step, model_object):
        self.step = step
        self.model_object = model_object
        
    def run(self, X_train_full, y_train_full, X_test, y_test, initial_queried, max_queried):

        (permutation, X_train, y_train) = get_random_samples(initial_queried, X_train_full, y_train_full)
        self.queried = initial_queried

        X_val = np.array([])
        y_val = np.array([])
        X_val = np.copy(X_train_full)
        X_val = np.delete(X_val, permutation, axis=0)
        y_val = np.copy(y_train_full)
        y_val = np.delete(y_val, permutation, axis=0)

        normalizer = Normalize()
        X_train, X_val, X_test = normalizer.normalize(X_train, X_val, X_test)
           
        self.clf_model = TrainModel(self.model_object)
        (X_train, X_val, X_test) = self.clf_model.train(X_train, y_train, X_val, X_test)
        active_iteration = 1
        self.clf_model.get_test_accuracy(1, y_test)

        while self.queried <= max_queried-self.step:

            active_iteration += 1
            self.queried += self.step
            (mc_permutation, X_subset, y_subset) = \
                get_random_samples(10, X_val, y_val) # 10 is the subset size
            # print('Indexes in the subset for X_val:', mc_permutation)
            # print ('Subset:', X_subset.shape, y_subset.shape, monte_carlo_permutation.shape)
            # print ('Train:', X_train.shape, y_train.shape, permutation.shape)

            cand_probs = self.clf_model.model_object.classifier.predict_proba(X_subset)
            # print("structure of cand_probs:", cand_probs)

            utils = []

            for i in range(len(X_subset)):
                new_train_X = X_train
                row_subset = X_subset[i]
                new_train_X = np.append(new_train_X, [row_subset], axis=0)
                util = 0
                new_label_y = np.random.randint(0, 9, size=len(X_subset))
                # new_label_y = np.random.choice([0, 1], size=len(X_subset),)
                # print("Newly assigned labels:", new_label_y)
                # To-do: random.randint is too inefficient
                for label in new_label_y:
                    new_train_y = y_train
                    new_train_y = np.append(new_train_y, label)
                    # print('Monte_carlo training set X:', new_train_X)
                    # print('Monte_carlo training set y:', new_train_y)
                    new_classifier = self.clf_model.model_object.classifier
                    new_classifier.fit(new_train_X, new_train_y)
                    new_probs = new_classifier.predict_proba(X_subset)
                    # new_preds = new_classifier.predict(X_subset)
                    # print("structure of new_probs:", cand_probs)
                    # util for log_loss
                    util += cand_probs[i][label] * log_loss(y_subset, new_probs)
                    # util for mse_loss
                    # util += cand_probs[i][label] * mse_loss(y_subset, new_preds)

                utils.append(util)
                
            uis = np.argsort(utils)
            # need to check validity
            # print ('Monte-carlo selected indexes:', uis)
  

            X_uncertain = [X_subset[i] for i in uis[:self.step]]
            y_uncertain = [y_subset[i] for i in uis[:self.step]]
            uncertain_samples = mc_permutation[uis[:self.step]]
            # print ('Monte-carlo selected indexes:', uncertain_samples)
            # print ('Monte-carlo selected samples:', X_uncertain)
            # print ('Monte-carlo selected outcomes:', y_uncertain)

            X_train, X_val, X_test = normalizer.inverse(X_train, X_val, X_test)   
            X_train = np.concatenate((X_train, np.array(X_uncertain)))
            y_train = np.concatenate((y_train, np.array(y_uncertain)))

            X_val = np.delete(X_val, uncertain_samples, axis=0)
            y_val = np.delete(y_val, uncertain_samples, axis=0)

            normalizer = Normalize()
            X_train, X_val, X_test = normalizer.normalize(X_train, X_val, X_test)               

            (X_train, X_val, X_test) = self.clf_model.train(X_train, y_train, X_val, X_test)
            self.clf_model.get_test_accuracy(active_iteration, y_test)

        return self.clf_model.accuracies

# %%
def pool_experiment(model,max_queried,initial_queried,step):

    (X, y) = fetch_data_mnist()

    # print("min/max:",min(y),max(y))

    kf = KFold(n_splits=4)
    for train_index, test_index in kf.split(X):
        X_train_full, X_test = X[train_index], X[test_index]
        y_train_full, y_test = y[train_index], y[test_index]
        
    act_alg = TheAlgorithm(step, model)
    accuracies = act_alg.run(X_train_full,y_train_full,X_test,y_test,initial_queried,max_queried)

    (permutation, X_train_selected, y_train_selected) = get_random_samples(initial_queried, X_train_full, y_train_full)
    original_accuracies=[]
    classifier_original = LogisticRegression(
            # penalty='l1',
            solver='newton-cg',
            tol=0.1
            )
    x_axis = []
    for i in range(initial_queried-1,max_queried,step):
        classifier_original.fit(X_train_selected[:i+1], y_train_selected[:i+1])
        y_pred_original = classifier_original.predict(X_test)
        original_accuracies.append(accuracy_score(y_test, y_pred_original)*100)
        x_axis.append(i+1)
    print("accuracies",accuracies)
    print("nonactive_accuracies",original_accuracies)
    plt.plot(x_axis, accuracies, 'r',label='active')
    plt.plot(x_axis, original_accuracies, 'blue',label='non-active')
    plt.legend()
    plt.xlabel('Sample Size')
    plt.ylabel('Accuracy')
    plt.show()

# %%
pool_experiment(LogModel,500,25,5)
# Out:
# Train set: (25, 64)
# Validation set: (1323, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 1
# Accuracy rate is 38.752784
# --------------------------------
# Train set: (30, 64)
# Validation set: (1318, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 2
# Accuracy rate is 36.080178
# --------------------------------
# Train set: (35, 64)
# Validation set: (1313, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 3
# Accuracy rate is 42.761693
# --------------------------------
# Train set: (40, 64)
# Validation set: (1308, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 4
# Accuracy rate is 44.543430
# --------------------------------
# Train set: (45, 64)
# Validation set: (1303, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 5
# Accuracy rate is 47.661470
# --------------------------------
# Train set: (50, 64)
# Validation set: (1298, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 6
# Accuracy rate is 53.452116
# --------------------------------
# Train set: (55, 64)
# Validation set: (1293, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 7
# Accuracy rate is 56.347439
# --------------------------------
# Train set: (60, 64)
# Validation set: (1288, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 8
# Accuracy rate is 59.465479
# --------------------------------
# Train set: (65, 64)
# Validation set: (1283, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 9
# Accuracy rate is 61.692650
# --------------------------------
# Train set: (70, 64)
# Validation set: (1278, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 10
# Accuracy rate is 63.474388
# --------------------------------
# Train set: (75, 64)
# Validation set: (1273, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 11
# Accuracy rate is 71.269488
# --------------------------------
# Train set: (80, 64)
# Validation set: (1268, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 12
# Accuracy rate is 71.492205
# --------------------------------
# Train set: (85, 64)
# Validation set: (1263, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 13
# Accuracy rate is 71.937639
# --------------------------------
# Train set: (90, 64)
# Validation set: (1258, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 14
# Accuracy rate is 74.164811
# --------------------------------
# Train set: (95, 64)
# Validation set: (1253, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 15
# Accuracy rate is 74.387528
# --------------------------------
# Train set: (100, 64)
# Validation set: (1248, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 16
# Accuracy rate is 74.387528
# --------------------------------
# Train set: (105, 64)
# Validation set: (1243, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 17
# Accuracy rate is 76.169265
# --------------------------------
# Train set: (110, 64)
# Validation set: (1238, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 18
# Accuracy rate is 76.614699
# --------------------------------
# Train set: (115, 64)
# Validation set: (1233, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 19
# Accuracy rate is 78.396437
# --------------------------------
# Train set: (120, 64)
# Validation set: (1228, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 20
# Accuracy rate is 78.396437
# --------------------------------
# Train set: (125, 64)
# Validation set: (1223, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 21
# Accuracy rate is 79.064588
# --------------------------------
# Train set: (130, 64)
# Validation set: (1218, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 22
# Accuracy rate is 77.282851
# --------------------------------
# Train set: (135, 64)
# Validation set: (1213, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 23
# Accuracy rate is 79.955457
# --------------------------------
# Train set: (140, 64)
# Validation set: (1208, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 24
# Accuracy rate is 81.514477
# --------------------------------
# Train set: (145, 64)
# Validation set: (1203, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 25
# Accuracy rate is 81.291759
# --------------------------------
# Train set: (150, 64)
# Validation set: (1198, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 26
# Accuracy rate is 79.732739
# --------------------------------
# Train set: (155, 64)
# Validation set: (1193, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 27
# Accuracy rate is 79.955457
# --------------------------------
# Train set: (160, 64)
# Validation set: (1188, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 28
# Accuracy rate is 82.182628
# --------------------------------
# Train set: (165, 64)
# Validation set: (1183, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 29
# Accuracy rate is 79.510022
# --------------------------------
# Train set: (170, 64)
# Validation set: (1178, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 30
# Accuracy rate is 81.514477
# --------------------------------
# Train set: (175, 64)
# Validation set: (1173, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 31
# Accuracy rate is 81.737194
# --------------------------------
# Train set: (180, 64)
# Validation set: (1168, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 32
# Accuracy rate is 84.187082
# --------------------------------
# Train set: (185, 64)
# Validation set: (1163, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 33
# Accuracy rate is 85.300668
# --------------------------------
# Train set: (190, 64)
# Validation set: (1158, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 34
# Accuracy rate is 83.073497
# --------------------------------
# Train set: (195, 64)
# Validation set: (1153, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 35
# Accuracy rate is 82.182628
# --------------------------------
# Train set: (200, 64)
# Validation set: (1148, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 36
# Accuracy rate is 82.405345
# --------------------------------
# Train set: (205, 64)
# Validation set: (1143, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 37
# Accuracy rate is 83.518931
# --------------------------------
# Train set: (210, 64)
# Validation set: (1138, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 38
# Accuracy rate is 85.300668
# --------------------------------
# Train set: (215, 64)
# Validation set: (1133, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 39
# Accuracy rate is 84.632517
# --------------------------------
# Train set: (220, 64)
# Validation set: (1128, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 40
# Accuracy rate is 83.964365
# --------------------------------
# Train set: (225, 64)
# Validation set: (1123, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 41
# Accuracy rate is 83.741648
# --------------------------------
# Train set: (230, 64)
# Validation set: (1118, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 42
# Accuracy rate is 85.523385
# --------------------------------
# Train set: (235, 64)
# Validation set: (1113, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 43
# Accuracy rate is 85.300668
# --------------------------------
# Train set: (240, 64)
# Validation set: (1108, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 44
# Accuracy rate is 87.305122
# --------------------------------
# Train set: (245, 64)
# Validation set: (1103, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 45
# Accuracy rate is 85.968820
# --------------------------------
# Train set: (250, 64)
# Validation set: (1098, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 46
# Accuracy rate is 88.195991
# --------------------------------
# Train set: (255, 64)
# Validation set: (1093, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 47
# Accuracy rate is 86.636971
# --------------------------------
# Train set: (260, 64)
# Validation set: (1088, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 48
# Accuracy rate is 87.082405
# --------------------------------
# Train set: (265, 64)
# Validation set: (1083, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 49
# Accuracy rate is 87.082405
# --------------------------------
# Train set: (270, 64)
# Validation set: (1078, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 50
# Accuracy rate is 87.305122
# --------------------------------
# Train set: (275, 64)
# Validation set: (1073, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 51
# Accuracy rate is 87.082405
# --------------------------------
# Train set: (280, 64)
# Validation set: (1068, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 52
# Accuracy rate is 86.636971
# --------------------------------
# Train set: (285, 64)
# Validation set: (1063, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 53
# Accuracy rate is 85.968820
# --------------------------------
# Train set: (290, 64)
# Validation set: (1058, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 54
# Accuracy rate is 86.859688
# --------------------------------
# Train set: (295, 64)
# Validation set: (1053, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 55
# Accuracy rate is 87.305122
# --------------------------------
# Train set: (300, 64)
# Validation set: (1048, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 56
# Accuracy rate is 87.527840
# --------------------------------
# Train set: (305, 64)
# Validation set: (1043, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 57
# Accuracy rate is 87.750557
# --------------------------------
# Train set: (310, 64)
# Validation set: (1038, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 58
# Accuracy rate is 87.527840
# --------------------------------
# Train set: (315, 64)
# Validation set: (1033, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 59
# Accuracy rate is 87.305122
# --------------------------------
# Train set: (320, 64)
# Validation set: (1028, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 60
# Accuracy rate is 88.864143
# --------------------------------
# Train set: (325, 64)
# Validation set: (1023, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 61
# Accuracy rate is 88.864143
# --------------------------------
# Train set: (330, 64)
# Validation set: (1018, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 62
# Accuracy rate is 89.755011
# --------------------------------
# Train set: (335, 64)
# Validation set: (1013, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 63
# Accuracy rate is 89.086860
# --------------------------------
# Train set: (340, 64)
# Validation set: (1008, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 64
# Accuracy rate is 89.977728
# --------------------------------
# Train set: (345, 64)
# Validation set: (1003, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 65
# Accuracy rate is 88.641425
# --------------------------------
# Train set: (350, 64)
# Validation set: (998, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 66
# Accuracy rate is 89.309577
# --------------------------------
# Train set: (355, 64)
# Validation set: (993, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 67
# Accuracy rate is 89.532294
# --------------------------------
# Train set: (360, 64)
# Validation set: (988, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 68
# Accuracy rate is 89.086860
# --------------------------------
# Train set: (365, 64)
# Validation set: (983, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 69
# Accuracy rate is 88.418708
# --------------------------------
# Train set: (370, 64)
# Validation set: (978, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 70
# Accuracy rate is 89.086860
# --------------------------------
# Train set: (375, 64)
# Validation set: (973, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 71
# Accuracy rate is 87.527840
# --------------------------------
# Train set: (380, 64)
# Validation set: (968, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 72
# Accuracy rate is 88.195991
# --------------------------------
# Train set: (385, 64)
# Validation set: (963, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 73
# Accuracy rate is 88.641425
# --------------------------------
# Train set: (390, 64)
# Validation set: (958, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 74
# Accuracy rate is 88.418708
# --------------------------------
# Train set: (395, 64)
# Validation set: (953, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 75
# Accuracy rate is 87.973274
# --------------------------------
# Train set: (400, 64)
# Validation set: (948, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 76
# Accuracy rate is 88.641425
# --------------------------------
# Train set: (405, 64)
# Validation set: (943, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 77
# Accuracy rate is 88.418708
# --------------------------------
# Train set: (410, 64)
# Validation set: (938, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 78
# Accuracy rate is 87.527840
# --------------------------------
# Train set: (415, 64)
# Validation set: (933, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 79
# Accuracy rate is 88.641425
# --------------------------------
# Train set: (420, 64)
# Validation set: (928, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 80
# Accuracy rate is 88.641425
# --------------------------------
# Train set: (425, 64)
# Validation set: (923, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 81
# Accuracy rate is 89.086860
# --------------------------------
# Train set: (430, 64)
# Validation set: (918, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 82
# Accuracy rate is 88.641425
# --------------------------------
# Train set: (435, 64)
# Validation set: (913, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 83
# Accuracy rate is 88.418708
# --------------------------------
# Train set: (440, 64)
# Validation set: (908, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 84
# Accuracy rate is 88.195991
# --------------------------------
# Train set: (445, 64)
# Validation set: (903, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 85
# Accuracy rate is 88.418708
# --------------------------------
# Train set: (450, 64)
# Validation set: (898, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 86
# Accuracy rate is 87.973274
# --------------------------------
# Train set: (455, 64)
# Validation set: (893, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 87
# Accuracy rate is 88.195991
# --------------------------------
# Train set: (460, 64)
# Validation set: (888, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 88
# Accuracy rate is 88.641425
# --------------------------------
# Train set: (465, 64)
# Validation set: (883, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 89
# Accuracy rate is 89.309577
# --------------------------------
# Train set: (470, 64)
# Validation set: (878, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 90
# Accuracy rate is 88.418708
# --------------------------------
# Train set: (475, 64)
# Validation set: (873, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 91
# Accuracy rate is 88.641425
# --------------------------------
# Train set: (480, 64)
# Validation set: (868, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 92
# Accuracy rate is 88.641425
# --------------------------------
# Train set: (485, 64)
# Validation set: (863, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 93
# Accuracy rate is 88.641425
# --------------------------------
# Train set: (490, 64)
# Validation set: (858, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 94
# Accuracy rate is 89.086860
# --------------------------------
# Train set: (495, 64)
# Validation set: (853, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 95
# Accuracy rate is 87.750557
# --------------------------------
# Train set: (500, 64)
# Validation set: (848, 64)
# Test set: (449, 64)
# --------------------------------
# Iteration: 96
# Accuracy rate is 89.532294
# --------------------------------
# accuracies [38.75278396436526, 36.080178173719375, 42.761692650334076, 44.543429844098, 47.66146993318486, 53.4521158129176, 56.347438752783965, 59.46547884187082, 61.69265033407573, 63.474387527839646, 71.26948775055679, 71.49220489977728, 71.93763919821826, 74.16481069042317, 74.38752783964365, 74.38752783964365, 76.16926503340757, 76.61469933184856, 78.39643652561247, 78.39643652561247, 79.06458797327394, 77.28285077951003, 79.9554565701559, 81.51447661469933, 81.29175946547885, 79.73273942093542, 79.9554565701559, 82.18262806236079, 79.51002227171492, 81.51447661469933, 81.73719376391982, 84.18708240534521, 85.30066815144765, 83.07349665924276, 82.18262806236079, 82.40534521158129, 83.51893095768375, 85.30066815144765, 84.63251670378618, 83.96436525612472, 83.74164810690424, 85.52338530066815, 85.30066815144765, 87.30512249443207, 85.96881959910914, 88.19599109131403, 86.63697104677061, 87.08240534521158, 87.08240534521158, 87.30512249443207, 87.08240534521158, 86.63697104677061, 85.96881959910914, 86.8596881959911, 87.30512249443207, 87.52783964365256, 87.75055679287304, 87.52783964365256, 87.30512249443207, 88.8641425389755, 88.8641425389755, 89.75501113585747, 89.086859688196, 89.97772828507794, 88.64142538975501, 89.30957683741649, 89.53229398663697, 89.086859688196, 88.41870824053451, 89.086859688196, 87.52783964365256, 88.19599109131403, 88.64142538975501, 88.41870824053451, 87.97327394209354, 88.64142538975501, 88.41870824053451, 87.52783964365256, 88.64142538975501, 88.64142538975501, 89.086859688196, 88.64142538975501, 88.41870824053451, 88.19599109131403, 88.41870824053451, 87.97327394209354, 88.19599109131403, 88.64142538975501, 89.30957683741649, 88.41870824053451, 88.64142538975501, 88.64142538975501, 88.64142538975501, 89.086859688196, 87.75055679287304, 89.53229398663697]
# nonactive_accuracies [66.815144766147, 69.48775055679288, 67.03786191536749, 65.70155902004454, 66.815144766147, 67.48329621380846, 67.48329621380846, 66.14699331848553, 68.37416481069042, 67.48329621380846, 65.25612472160356, 67.03786191536749, 64.81069042316258, 67.26057906458797, 66.36971046770601, 63.474387527839646, 68.59688195991092, 65.70155902004454, 65.47884187082406, 65.25612472160356, 66.59242761692651, 66.59242761692651, 68.8195991091314, 66.14699331848553, 68.37416481069042, 67.03786191536749, 66.815144766147, 67.03786191536749, 65.47884187082406, 65.70155902004454, 67.92873051224944, 67.48329621380846, 64.81069042316258, 66.59242761692651, 64.58797327394208, 63.474387527839646, 63.91982182628062, 66.36971046770601, 67.26057906458797, 64.14253897550111, 64.3652561247216, 67.70601336302894, 67.26057906458797, 67.70601336302894, 66.59242761692651, 65.92427616926503, 68.59688195991092, 65.70155902004454, 66.815144766147, 68.37416481069042, 69.04231625835189, 64.14253897550111, 65.92427616926503, 68.15144766146993, 67.48329621380846, 66.36971046770601, 64.58797327394208, 63.91982182628062, 67.70601336302894, 69.93318485523386, 66.59242761692651, 67.48329621380846, 67.03786191536749, 63.02895322939867, 65.70155902004454, 67.26057906458797, 67.26057906458797, 65.70155902004454, 68.37416481069042, 67.03786191536749, 64.81069042316258, 66.36971046770601, 65.70155902004454, 67.03786191536749, 63.91982182628062, 67.70601336302894, 67.70601336302894, 65.25612472160356, 69.48775055679288, 68.8195991091314, 67.03786191536749, 67.70601336302894, 65.92427616926503, 63.69710467706013, 64.58797327394208, 64.58797327394208, 63.91982182628062, 65.70155902004454, 67.92873051224944, 65.70155902004454, 67.03786191536749, 67.03786191536749, 65.70155902004454, 64.81069042316258, 68.37416481069042, 65.70155902004454]
